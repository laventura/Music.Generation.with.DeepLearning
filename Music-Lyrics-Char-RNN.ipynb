# %% [markdown]
# # Generating Irish Folk Tunes and Lyrics - using LSTM
#
# This project uses Long Short-term Memory (LSTM) -based recurrent neural network (RNN) to generate music and lyrics using the provided music datasets.
#
# This is based on Kadenze's **Creative Applications for Deep Learning** course (by  P.K. Mital), and Andrej Karpathy's excellent blog post **The Unreasonable Effectiveness of Recurrent Neural Networks** (http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
#
# Project is divide in two parts:
# 1. **Generating (Irish) Folk tunes** - using music transcribed in ABC Notation
#
# 2. **Generating Bob Dylan lyrics** - using Bob Dylan's songs archive

# %% [markdown]
# ## Setting up the Music datasets
#
#
# One chief problem for me was to figure out how to represent music in text. _Unfortunatey, I do not read sheet music._ However, I came across the **ABC notation for music** (link: http://abcnotation.com/) that shows how music can be represented succinctly in across a few key dimensions: Key (scale), Beat, Notes (and melody). Note that this does not, by itself, make music easier to understand. It does, however, makes is super easy for MIDI programs to play the .abc formatted music.
#
# This site includes resources to major contributions of various music datasets transcribed in the ABC format.
#
# As a lover of folk tunes, particularly Irish tunes, I found these datasets immensely helpful.
#
# - **O'Neill's Irish Music dataset** (Source: http://trillian.mit.edu/~jc/music/book/oneills/1850/X/ )
# - **Cobb's Irish Music dataset** (Source: http://cobb.ece.wisc.edu/irish/Tunebook.html )
# - **Nottingham Music dataset** (ABC version of Nottingham music dataset: http://abc.sourceforge.net/NMD/)
#
# - **Irish Music** -- combined from Cobb's and O'Neills. I wrote a scraper to scrape O'Neill's and Cobb's data from the sites, clean up the data, and combine them in one file.
#
#
#
# ## Lyrics for Bob Dylan Songs
#
# I love Bob Dylan. I have been listening to his music for a while. As [he recently won the Nobel Prize for Literature](http://www.npr.org/sections/thetwo-way/2016/10/13/497780610/bob-dylan-titan-of-american-music-wins-the-2016-nobel-prize-in-literature) with some even questioning whether his writings are music or poetry (see: https://www.theguardian.com/music/2016/oct/15/bob-dylan-deserves-nobel-laureate-literature-singular-talent), I thought it would be fun to generate our own _Dylan-eseque_ lyrics and see if the are, ahem, Nobel worthy. 😊
#
# I scraped the Bob Dylan songs site (http://bobdylan.com/songs/), downloaded the lyrics separately and combined them in one text file. It comes down a mere 700KB dataset, which is _tiny_ for the purposes of training an RNN.
#
# Copyright for all the lyrics is held by the respective owners, not me.

# %%
# To display Audio and Video output
from IPython.display import Audio
from IPython.display import YouTubeVideo

# %%
# First check the Python version
import sys
if sys.version_info < (3,4):
    print('You are running an older version of Python!\n\n',
          'You should consider updating to Python 3.4.0 or',
          'higher as the libraries built for this course',
          'have only been tested in Python 3.4 and higher.\n')
    print('Try installing the Python 3.5 version of anaconda'
          'and then restart `jupyter notebook`:\n',
          'https://www.continuum.io/downloads\n\n')

# Now get necessary libraries
try:
    import os
    import numpy as np
    import matplotlib.pyplot as plt
    from skimage.transform import resize
    from skimage import data
    from scipy.misc import imresize
    from scipy.ndimage.filters import gaussian_filter
    import IPython.display as ipyd
    import tensorflow as tf
    from libs import utils, gif, datasets, dataset_utils, nb_utils
except ImportError as e:
    print("Make sure you have started notebook in the same directory",
          "as the provided zip file which includes the 'libs' folder",
          "and the file 'utils.py' inside of it.  You will NOT be able",
          "to complete this assignment unless you restart jupyter",
          "notebook inside the directory created by extracting",
          "the zip file or cloning the github repo.")
    print(e)

# We'll tell matplotlib to inline any drawn figures like so:
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Bit of formatting because I don't like the default inline code style:
from IPython.core.display import HTML
HTML("""<style> .rendered_html code { 
    padding: 2px 4px;
    color: #c7254e;
    background-color: #f9f2f4;
    border-radius: 4px;
} </style>""")
# Out:
# <style> .rendered_html code {
#     padding: 2px 4px;
#     color: #c7254e;
#     background-color: #f9f2f4;
#     border-radius: 4px;
# } </style>

# %%
# Imports
# %pylab
import tensorflow as tf
from six.moves import urllib
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# /Users/aa/Developer/miniconda/envs/py35/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['resize']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# Print TF version
print(tf.__version__)
# Out:
# 0.9.0

# %% [markdown]
# ### Motivation and Representing Music in ABC notation
#
# I love Irish folk tunes. A few of my fav tunes are [Julia Delaney](https://www.youtube.com/watch?v=9-1BtokSbmw), [Cooley's Reel](https://www.youtube.com/watch?v=uOaBP-mxXVc), [St. Anne's Reel](https://www.youtube.com/watch?v=VSZAQi3xRMU), all traditional tunes, played on a fast beat.

# %%
# Sample Videos from YouTube
YT_JULIA = '9-1BtokSbmw'   # Julia Delaney - Bothy Band
YT_ST_ANNES = 'fA7iedRBJrs'  # St Anne's Reel - Dubliners
YT_COOLEYS = 'uOaBP-mxXVc'   # Cooley's Reel - Kevin Burke; start at 15s

YouTubeVideo(YT_JULIA)

# %% [markdown]
# So what does Julia Delaney look like when transcribed in .ABC format?

# %%
## Define Filenames: use .abc or .ogg extension to actually play the files!
IN_JULIA = 'julia-delaney-X174'   
IN_ST_ANNES = 'st-annes-X322'
IN_COOLEYS = 'cooleys-X51'

# %%
# Show Julia Delaney
with open(IN_JULIA + '.abc', 'r') as fin:
    t = fin.read()
print(t)
# Out:
# X:174
# T:Julia Delaney
# Z: id:dc-reel-161
# M:C
# L:1/8
# K:D Minor
# A|dcAG F2DF|E2CE F2DF|dcAG F2DF|Add^c defe|!
# dcAG F2DF|E2CE F2DF|dcAG F2DF|Add^c d3:|!
# e|fede fagf|ecgc acgc|fede fagf|edcA Adde|!
# fede fagf|ecgc acgc|fedf edcA|Add^c d3:|!

# %% [markdown]
# As can be seen, the format is incredibly compact.
# Each line begins with a single letter field (except for notes).
# - **X** denotes a reference number
# - **M** denotes Meter
# - **K** denotes the Key
# - **L** denotes the beats
# - **T** denotes the Title
# - **Z** denotes the transcription
# The rest are notes that denote the melody for the song.
#
# As can be seen, this text data is useful to train an RNN to generate a similarly structed .abc, which can then be converted into .MIDI format, and from there to .WAV or .OGG format to play.

# %% [markdown]
# ## Part 1 -- Generating Music Text
#
# Now the challenge is generating some foot tapping music.

# %%
#### Datasets
ONEILL_IRISH =  "oneills-irish-music.txt"
COBBS_IRISH =  "cobbs-irish.txt"
NOTTINGHAM_FOLK =  'nottingham-music-abc.txt'
IRISH_MUSIC =  'irish-music.txt'    # This combines COBBS and O'Neill datasets

BOB_DYLAN_TXT = "bobdylan_songs.txt"  # Bob Dylan Song lyrics

# %% [markdown]
# ### Lets define a few funcs to use later
# Build the model
# Train the model
# Infer from the model

# %%
## Build the model 
"""  Builds an RNN model, using given training txt 
"""

import collections 

def build_model(txt,       # text from the dataset
                batch_size=20,
                sequence_length=50,
                n_layers=2,
                n_cells=100,
                gradient_clip=5.0,
                learning_rate=0.001,
                model_type='lstm'):  # model type: LSTM, RNN or GRU

    # Create LSTM, RNN, or GRU cell
    if model_type == 'lstm':
        cell_func = tf.nn.rnn_cell.BasicLSTMCell
    elif model_type == 'rnn':
        cell_func = tf.nn.rnn_cell.BasicRNNCell
    elif model_type == 'gru':
        cell_func = tf.nn.rnn_cell.GRUCell
    else:
        raise Exception("model_type not supported: {}".format(model_type))

    # get the vocab from the txt
    vocab = list(set(txt))
    vocab.sort()
    # num chars
    n_chars = len(vocab)
    # encoder, decoder
    encoder = collections.OrderedDict(zip(vocab, range(n_chars)))
    decoder = collections.OrderedDict(zip(range(n_chars), vocab))

    # Placeholder for X (input) and Y (output)
    X = tf.placeholder(tf.int32, [None, sequence_length], name='X')
    Y = tf.placeholder(tf.int32, [None, sequence_length], name='Y')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

    # we first create a variable to take us from our one-hot representation to our LSTM cells
    with tf.variable_scope('embedding'):
        embedding = tf.get_variable("embedding", [n_chars, n_cells])
        # each seq element will be connected to n_cells
        Xs = tf.nn.embedding_lookup(embedding, X)
        # To create a recurrent network, we're going to need to slice our sequences into individual inputs.
        # That will give us timestep lists which are each batch_size x input_size. Each character will then be connected to a recurrent layer composed of n_cells LSTM units.
        # then slice each sequence element
        Xs = tf.split(1, sequence_length, Xs)
        # remove the singleton sequence
        Xs = [tf.squeeze(Xi, [1]) for Xi in Xs]

    # use model_type arg
    with tf.variable_scope('rnn'):
        cells = cell_func(
            num_units=n_cells,
            forget_bias=0.0,
            state_is_tuple=True)
        initial_state = cells.zero_state(tf.shape(X)[0], tf.float32)

        if n_layers > 1:
            cells = tf.nn.rnn_cell.MultiRNNCell(
                    [cells] * n_layers,
                    state_is_tuple=True)
            initial_state = cells.zero_state(tf.shape(X)[0], tf.float32)

        # config dropout
        cells = tf.nn.rnn_cell.DropoutWrapper(
            cells, output_keep_prob=keep_prob)
        # output
        outputs, final_state = tf.nn.rnn(
            cells, Xs,
            initial_state=initial_state)
        outputs_flat = tf.reshape(tf.concat(1,
            outputs), [-1, n_cells])

    # prediction
    with tf.variable_scope('prediction'):
        # weights
        W = tf.get_variable(
            "W",
            shape=[n_cells, n_chars],
            initializer=tf.random_normal_initializer(stddev=0.1))  # TODO: another initializer?
        # bias
        b = tf.get_variable(
            "b",
            shape=[n_chars],
            initializer=tf.random_normal_initializer(stddev=0.1))  # TODO: check another init??
        # Find output prediction of every single char in the minibatch
        # pre-activation prediction is logits
        logits = tf.matmul(outputs_flat, W) + b
        # get probabilistic version by calculating the softmax
        probs = tf.nn.softmax(logits)
        # then find the index of max probability
        Y_pred = tf.argmax(probs, 1)

    # Loss - compute
    with tf.variable_scope('loss'):
        # compute mean cross entropy loss for each output
        Y_true_flat = tf.reshape(tf.concat(1, Y), [-1])
        loss = tf.nn.sparse_softmax_cross_entropy_with_logits(logits, Y_true_flat)
        mean_loss = tf.reduce_mean(loss)

    # optimizer
    with tf.name_scope('optimizer'):
        optimizer = tf.train.AdamOptimizer(
            learning_rate=learning_rate)
        gradients = []

        clip = tf.constant(gradient_clip, name="clip")
        for grad, var in optimizer.compute_gradients(mean_loss):
            gradients.append( (tf.clip_by_value(grad, -clip, clip), var))
        updates = optimizer.apply_gradients(gradients)

    model = {'X': X,
            'Y': Y,
            'logits': logits,
            'probs': probs,
            'Y_pred': Y_pred,
            'cost': mean_loss,
            'updates': updates,
            'initial_state': initial_state,
            'final_state': final_state,
            'encoder': encoder,
            'decoder': decoder,
            'vocab_size': n_chars,
            'keep_prob': keep_prob
            }
    return model

# %%
## Train the model
"""  Trains an RNN, using given txt dataset
    Requires txt from training dataset.
    Highly recommended to use ckpt_name to customize model name to save to/restore from
    
    Notably, this code uses max_iter number of iterations to run
    
"""

def train(txt,                         # text from dataset used for training
            batch_size=100,
            sequence_length=150,
            n_cells=100,
            n_layers=3,
            learning_rate=0.0001,
            max_iter=50000,            # num of iterations to train for
            gradient_clip=5.0,
            ckpt_name="model.ckpt",    # model to save to, or restore from 
            keep_prob=1.0,
            model_type='lstm'):

    g = tf.Graph()

    with tf.Session(graph=g) as sess:
        model = build_model(txt=txt,
                            batch_size=batch_size,
                            sequence_length=sequence_length,
                            n_layers=n_layers,
                            n_cells=n_cells,
                            gradient_clip=gradient_clip,
                            learning_rate=learning_rate,
                            model_type=model_type)

        init_op = tf.initialize_all_variables()
        saver = tf.train.Saver()
        # Run it
        sess.run(init_op)
        # if saved model exists, use it
        if os.path.exists(ckpt_name):
            saver.restore(sess, ckpt_name)
            print("...Model restored: ", ckpt_name)

        cursor = 0
        it_i = 0
        print_step = 100   # change this to, say 500 or 1000, to print less frequently
        avg_cost = 0

        while it_i < max_iter:
            Xs, Ys = [], []
            for bn in range(batch_size):
                Xs.append([model['encoder'][ch]
                            for ch in txt[cursor: cursor + sequence_length]])
                Ys.append([model['encoder'][ch]
                            for ch in txt[cursor+1: cursor + sequence_length + 1]])
                cursor += sequence_length
                if (cursor + 1) >= len(txt) - sequence_length - 1:   # reaching end of seq
                    cursor = np.random.randint(0, high=sequence_length)

            feed_dict = {model['X']: Xs,
                        model['Y']: Ys,
                        model['keep_prob']: keep_prob}
            out = sess.run([model['cost'], model['updates']], feed_dict=feed_dict)
            avg_cost += out[0]

            if (it_i % print_step == 0) and it_i > 0:
                probs = sess.run(model['probs'], feed_dict={
                model['X']: np.array(Xs[-1])[np.newaxis],
                model['keep_prob']: 1.0})
                print(probs.shape, 'min:', np.min(probs), 'max:', np.max(probs), 'mean:', np.mean(probs), 'std:', np.std(probs))

                if isinstance(txt[0], str):
                    # print orig string (prime???)
                    orig = [model['decoder'][ch] for ch in Xs[-1]]
                    # print('original:[', len(orig), ']', '\n', "".join( orig ))

                    # print max guess
                    amax = []
                    for pr in probs:
                        amax.append( model['decoder'][np.argmax(pr)])
                    # print('synth(amax)[', len(amax), ']:\n', "".join(amax))

                    # print w/ sampling
                    samp = []
                    for pr in probs:
                        pr = pr.astype(np.float64)
                        pr = pr / pr.sum()
                        idx = np.argmax(np.random.multinomial( 1, pr.ravel()))
                        samp.append(model['decoder'][idx])
                    # print('synth(samp)[', len(samp), ']:\n', "".join(samp))

                print(it_i, avg_cost / print_step)
                avg_cost = 0

                # save model with global_step number
                save_path = saver.save(sess, "./" + ckpt_name, global_step=it_i)
                print("--- Model saved to: %s" % save_path)

            print(it_i, out[0], end='\r')
            it_i += 1

        return model

# %%
### Sample (synthesize data) from a pre-trained model
"""
    Using a pre-trained model, generate synthetic data
    Must pass in:
    - txt:  txt from the training dataset
    - ckpt_name:  name of the pre-trained model
    - n_iterations: num of iterations to generate data for.
    
    The params of the model must match training model (e.g. n_layers, n_cells, learning_rate, ckpt_name)
    
"""

def infer(txt, ckpt_name, n_iterations, n_cells=256, n_layers=3,
        learning_rate=0.001, gradient_clip=5.0,
        init_value=[0], keep_prob=1.0, sampling='prob',
        temperature=1.0):

    print("### About to infer...")
    g = tf.Graph()
    with tf.Session(graph=g) as sess:
        sequence_length = len(init_value)
        model = build_model(txt=txt,
                            batch_size=1,
                            sequence_length=sequence_length,
                            n_layers=n_layers,
                            n_cells=n_cells,
                            gradient_clip=gradient_clip,
                            learning_rate=learning_rate)

        init_op = tf.initialize_all_variables()
        saver = tf.train.Saver()
        sess.run(init_op)

        if os.path.exists(ckpt_name):
            saver.restore(sess, ckpt_name)
            print("### Model restored: ", ckpt_name)

        state = []
        synth = [init_value]
        for fs in model['final_state']:
            state += sess.run( [fs.c, fs.h], feed_dict={
                    model['X']: [synth[-1]],
                    model['keep_prob']: keep_prob})

        # run till n_iterations
        for i in range(n_iterations):
            feed_dict = {   model['X']: [synth[-1]],
                            model['keep_prob']: keep_prob}
            state_updates = []
            for state_i in range(n_layers):
                feed_dict[model['initial_state'][state_i].c] = state[state_i * 2]
                feed_dict[model['initial_state'][state_i].h] = state[state_i * 2 + 1]
                state_updates.append(model['final_state'][state_i].c)
                state_updates.append(model['final_state'][state_i].h)

            probs = sess.run(model['probs'], feed_dict=feed_dict)[0]
            if sampling == 'max':   # argmax only
                probs = np.argmax(probs)
            else:   # sampling is prob
                probs = probs.astype(np.float64)
                probs = np.log(probs) / temperature
                probs = np.exp(probs) / np.sum(np.exp(probs))
                probs = np.random.multinomial(1, probs.ravel())
                probs = np.argmax(probs)
            # get current state
            state = [sess.run(sn_i, feed_dict=feed_dict)
                     for sn_i in state_updates ]
            synth.append([probs])
            print(model['decoder'][probs], end='')
            sys.stdout.flush()
        print(np.concatenate(synth).shape)
    rv = [ model['decoder'][ch] for ch in np.concatenate(synth) ]
    print("".join(rv))
    return rv

# %% [markdown]
# ## Let's generate some Irish folk tunes!
#
# Read in the combined Cobb's and O'Neill's dataset, and use it to train the network

# %%
## Let's generate some music!

# 1 - Dataset for Irish music  - combining both Cobb's and O'Neill's Irish music transcription
with open(IRISH_MUSIC, "r") as fin:
    irish_txt = fin.read()

print("Dataset len: ", len(irish_txt))
# Out:
# Dataset len:  987677

# %% [markdown]
# ### Define parameters for the network to create
#
# To create an RNN, specify the *model_type* as one 'lstm', 'rnn', or 'gru'.  In general, the LSTM type networks have shown to be more effective (per Karpathy)
#
# Specify these params:
# - batch_size:  sequences in a mini batch
# - sequence_length: number of characters in a sequence
# - n_cells: number of cells in the (hidden) RNN layers
# - n_layers: number of layers in the RNN
# - ckpt_name: unique name for the model; used to save the model or restore from it
# - learning_rate: how fast or slow the network should learn (typically, 0.001, but can be set to 0.0001)
#
# Params not yet defined (TODO):
# - decay_rate: schedule to taper off the learning rate
# -

# %%
# 2 - Define model params
# Number of sequences in a mini batch
batch_size = 64

# Num of characters in a seqence
sequence_length = 100

# Num of cells in LSTM
n_cells = 256

# Num of LSTM layers
n_layers = 3

# type of network
model_type = 'lstm'

# checkpoint name - 
ckpt_name = 'irish.ckpt'

# learning rate
learning_rate = 0.001

# %%
# 3 - Call Train func
model = train(txt=irish_txt, 
             batch_size=batch_size,
             sequence_length=sequence_length,
             n_cells=n_cells,
             n_layers=n_layers,
             learning_rate=learning_rate,
             max_iter=50001,
             model_type=model_type,
             ckpt_name=ckpt_name)
# Out:
# (100, 95) min: 6.27683e-06 max: 0.263478 mean: 0.0105263 std: 0.0240486
# original:[ 100 ]
#  Michael D. Long, 9/29/98
# K:G
# (3(DEF)|G2GG G2G2|BGBd gdBG|D2DD D2D2|FDFA dcAF|\
# G2GG G2G2|
# BGBd g2 z2
# synth(amax)[ 100 ]:
#  :
#
#
# aaaaa
#
#
#
#
# ::GGG
#
# synth(samp)[ 100 ]:
#  , )2fZ g4Ka
# klIX4aa:
#
#
# z2G{A)dG2B B| c2GAAAE| BEcd/cAX  GBD(Ddd2B
#
# F
# B(e ))BG | e2FBG2e d G|A .dC
# 100 3.4925229764
# --- Model saved to: ./irish.ckpt-100
# (100, 95) min: 1.0864e-06 max: 0.951872 mean: 0.0105263 std: 0.0394211
# original:[ 100 ]
#  rs <jc@trillian.mit.edu>
# N:"Spirited"
# M:C
# L:1/8
# K:Dm
# d^cde f2(ed) | (cd)(cA) G2FE | F2FD FGAB | AGA^
# synth(amax)[ 100 ]:
#  ll
# :O 'eills  ........
# N:""aann
# ::1/L:1/8
# K:G
#
# (2    |2 |2  |d(d2  (2) |2 ||| (2 | |    | (2  |
# synth(samp)[ 100 ]:
#  aBNcitidil.ssag
# asme.btnZ::"ayitdcnhW9T1CL:T1
#
# L:sG
# /D)dc|d) (f) |cdcE2 ]2)|A2 |2D G2| |||A  ( }2 )|
# 200 2.86321082115
# --- Model saved to: ./irish.ckpt-200
# (100, 95) min: 3.09111e-07 max: 0.801378 mean: 0.0105263 std: 0.0420678
# original:[ 100 ]
#  |E3F ABce|a2ge faec|cBBA B2cB|!
# A2cA B2AF|E3F ABce|a2ge faec|BABc A4:|!
# E2GE BEGE|A2cA eAcA|B2^dB fB
# synth(amax)[ 100 ]:
#
# F  G2A||ffgg eda||BAAA A2A||B
# d2B  B2d||B2GFD2A||ffgg edg||BAAA B2A|!
#
# |   G2F||B2AA A2A||BAAAd BdA
# synth(samp)[ 100 ]:
#  AGB/F>BAffgaadfcge|BcBFdc2|d/B
# X)d B(AcdE:FE2DGAG|dd2ffede|effGd:BGz|!
# A|D  d2A|dc2EA|AaA||BABGA fcG
# 300 2.29344990015
# --- Model saved to: ./irish.ckpt-300
# (100, 95) min: 3.37842e-07 max: 0.969576 mean: 0.0105263 std: 0.0464982
# original:[ 100 ]
#  :1/8
# K:D
# A3 G FAdB|AGFD EA, ((3A,B,A,)|ABAG FAdB|ABda fd d2 Hx:|
# Tf2 df Te2 df|afeg fBBg|Tf2 df Te2
# synth(amax)[ 100 ]:
#   /8
# T:G
# (2 (2 2   BGGG (2A |GAA)F)   | GAG G2Ad|BGAd geB|  | ||
# ||e    | d |  g2ed |eBA eee    | d |
# synth(samp)[ 100 ]:
#  [/8
# K:B
# d|c(2(2A |AGdD DFd: AABEFGz (
# 3AG)(cFc|(e~e gedBcAA |
# B dB(Ag  Be  dege d"eAc|dcdggd | e e
# 400 2.11612712979
# --- Model saved to: ./irish.ckpt-400
# (100, 95) min: 9.19461e-09 max: 0.995543 mean: 0.0105263 std: 0.0622391
# original:[ 100 ]
#  D|HD6||
#
# X:597
# T:Bend of the River., The
# T:caime na a.mne.
# R:air
# N:"Slow."
# B:O'Neill's 597
# Z:Transcr
# synth(amax)[ 100 ]:
#   GG2
#
#
# X:13
#
# T:Thl  Ba Oae Oal  i  Fhe M: anle Binha e r
# N:"insN:"Ciol
# N:O'Neill's 34
#
# Z:Transcri
# synth(samp)[ 100 ]:
#  )GG>
#
#
# X:183
# TJWolh Fa Oy
#  Aaih i  cOeeM: oslo
# Oin.teo
# M: ineL:iSeow iSN:O'Neill's 342
# M:Transcre
# 500 1.95472994089
# --- Model saved to: ./irish.ckpt-500
# (100, 95) min: 2.56766e-08 max: 0.996612 mean: 0.0105263 std: 0.0643903
# original:[ 100 ]
#  : id:dc-reel-50
# M:C
# L:1/8
# K:G Major
# G2AG FGAD|G2AG AdcA|G2AG FGAg|fdcA dBcA:|!
# dgg2 fgag|dgg2 agfe|d
# synth(amax)[ 100 ]:
#  |1d:dc-jeel-1
#
# M:6
# L:1/8
# K:D Major
# A|   AGE||AE   GGB||AE   GGEB|!eB  ABA|||!
# Beg  eee||fee  afe||fB
# synth(samp)[ 100 ]:
#  U|dederoeil-7s
# M:6|L:1/8
# K:G .Ejor
# D>   cBE||AF   dGBB||2EB FAFB|fdB :(cB|||!
# dee eeee||eee  feea|dG
# 600 1.78095741868
# --- Model saved to: ./irish.ckpt-600
# (100, 95) min: 2.76875e-08 max: 0.994481 mean: 0.0105263 std: 0.0521271
# original:[ 100 ]
#  de (~fe)ec|dBAF EDB,E|
# ABde ~(fe)ef|dfaf edBd|(3fga ec dBAd|(3Bcd AF EDD2|]
#
# X:1332
# T:Beamish's Goat
# synth(amax)[ 100 ]:
#   ddffedd |dBAG G2Dd||DD2Ae fffg)d |gegg efBA|eeegeggfAd2A||eeeAdeeAFG2D||
#
#
# X:1111
# T:Talnsn  s Mang
#
# synth(samp)[ 100 ]:
#  tcdfd>g{2Ad2EG EDDBF|ADABdgfa3g)f |gedf efBAcaGddg (aGGAGGBBcfAAgeBAF2D||E
# dX:1221
# T:Tabrbk e
#  Riuwe
# 700 1.72277153373
# --- Model saved to: ./irish.ckpt-700
# (100, 95) min: 1.64648e-07 max: 0.941723 mean: 0.0105263 std: 0.0589177
# original:[ 100 ]
#   | d2 B G2 Bc | d2 d2 edBG | A6 d2 |
# e2 de g2 ge | d3 B G2 Bc | d2 d2 cABG | E6 G>A |
# B3 A B>Bce | d
# synth(amax)[ 100 ]:
#  | d2 c2|2 |2 | d2 d2 c2   | G2 |2 |||2 d2 |2 |2 | d2 (2A2 |2 | d2 d2 c2   | G2 G2G | |2 A2A2c   | d2
# synth(samp)[ 100 ]:
#  _ B3/d d2 (  | d2ece c    | E2GB2dc (2 dB fef|/ |
# da 23d>|A2 |
# B2cAABz2   | G6 D2G-c A2 (2GAc  e| de
# 800 1.65149194837
# --- Model saved to: ./irish.ckpt-800
# (100, 95) min: 5.25059e-08 max: 0.992459 mean: 0.0105263 std: 0.0593938
# original:[ 100 ]
#  :|!
# A|def a3|baf afe|def afe|dBB B2A|!
# def a3|baf a2f|g3 f3|edB B2:|!
# A|def fef|fef fef|def fef|edB
# synth(amax)[ 100 ]:
#  |
#
#
# |B2f gg fgg gge|dBf ggd|dBA AA |B
# A2f gggfag gg |af fe|adB AA |!
#
# |d2f ged|ged ged|gff ged|gdc A
# synth(samp)[ 100 ]:
#  Q9
# D3 2f g> g2g efa|d2f ggfcde AA2e|B
# D2fdgggfgg ag||efgfb|efB c3B|!
# A|cBd dagdded eed|gef fed|gdc e
# 900 1.5378072989
# --- Model saved to: ./irish.ckpt-900
# (100, 95) min: 5.88613e-08 max: 0.985501 mean: 0.0105263 std: 0.0616546
# original:[ 100 ]
#  | A2 d FDF G2 E | A2 d FDF FDF | BAB D2 F G2 E :|
# |: D2 d AGF AGF | D2 d AGF G2 E | D2 d AGF AGF | B
# synth(amax)[ 100 ]:
#   d2 A c2D |2   | GB A c2D |2D | GGG c2 : |2   ||
#
# : B  G c2F |2F | GF D c2F |2   | GF D c2F |2E | GG
# synth(samp)[ 100 ]:
#
# BBdA O2G||2DG G AGFd B2F |FD | GGG AFFg |B H ||
#
# :    A GG  G2A A D eE g2F cA A : DA D e2F D2E | EG
# 1000 1.51168179274
# --- Model saved to: ./irish.ckpt-1000
# (100, 95) min: 6.02343e-10 max: 0.99795 mean: 0.0105263 std: 0.0819122
# original:[ 100 ]
#   Chambers <jc@trillian.mit.edu>
# N: "Slow"
# N: "Collected by F.O'Neill"
# K:G
# BA \
# | GE D2 DE | G2 B2 GB
# synth(amax)[ 100 ]:
#  (2hnbers <jc@trillian.mit.edu>
# M: "Mlow"
# N: "Collected by J.O'Neill"
# B:G
# (2 \
# | (2DG2 (2 | G2 (2 A2
# synth(samp)[ 100 ]:
#  doaly rs <jc@trillian.mi..ed->
# M: "CliweiN: "Mollected by J. 'Neill"
# B:EseG2G
# | B>D(2 .E | FA (  BG
# 1100 1.46848304391
# --- Model saved to: ./irish.ckpt-1100
# (100, 95) min: 3.52254e-08 max: 0.972561 mean: 0.0105263 std: 0.0652519
# original:[ 100 ]
#  B3 A BedB|AGED EFGA|B3 c BAGF|E4 z||
# d ef|g3 f fedB|dB Gz def|g3 f fedB|e4 z ddd|
# b3a ageg|dB G z FG
# synth(amax)[ 100 ]:
#    A2|2|||G2G2 G2G||!2 A2d2|||G2 G2!
#
# ||2|g2 f2g2|||A2GG2 G2||!2 f2g2|||!2 (2g2||!e2  g2f||f2G(2G2G2|
# synth(samp)[ 100 ]:
#    AB:cgc|A3GG E2c |BB G2B2|||G2| |]
# |/bfBg3 {2e2|||B3AA2 G2||g2 g3B2|:|G2 (2e2 |
# g3  f2ff|g22B2B f2|
# 1400 1.32757907033
# --- Model saved to: ./irish.ckpt-1400
# (100, 95) min: 9.59603e-09 max: 0.992561 mean: 0.0105263 std: 0.0708311
# original:[ 100 ]
#  A2 AcBA | G2B2 BdcB | A2A2 Acea | gfed cBAG |
#              A2A2 AcBA | G2B2 BdcB | Acea gfed | c2A2
# synth(amax)[ 100 ]:
#    A2 A|| G2 G G2BB | A2 2 A2ec |
# b2ed cAAG |
# |             2 2  2dA | G2 G G2BB | A2dc  eed | cB 2 A
# synth(samp)[ 100 ]:
#  2:G2dA |
# B2AG A2BB | BDDA EGec |2f^gd eBAc A
# | c     f F   c B A2dA | B2 G GGcd | A2ed a2edc: (BeG A
# 1500 1.2553135854
# --- Model saved to: ./irish.ckpt-1500
# (100, 95) min: 8.46436e-11 max: 0.999762 mean: 0.0105263 std: 0.0884682
# original:[ 100 ]
#  her's March
# N:"Collected by Hartnett"
# B:O'Neill's 867
# Z:Transcribed by Dan G. Petersen, dangp@post6.
# synth(amax)[ 100 ]:
#  enss Faooh
# M:"Collected by Farteett"
# Z:O'Neill's 660
# Z:Transcribed by Dan G. Petersen, dangp@post6.t
# synth(samp)[ 100 ]:
#   d s norce
# K:"Sollected by Bars,itt
#
# B:O'Neill's 613
# Z: ranscribed by Dan  . Petersen, dangp@post6.t
# 1600 1.29617364645
# --- Model saved to: ./irish.ckpt-1600
# (100, 95) min: 4.79017e-09 max: 0.98996 mean: 0.0105263 std: 0.0663324
# original:[ 100 ]
#  2 FG | A>f gf ed | c2 d>c AG | F2 G>F ED |
# | D4    c2 | f2  A2 A2 | c3   d e2 | f4 ((3gfe) |
# | d4 ((
# synth(amax)[ 100 ]:
#   d2|A A2Geg2 e2B| c2 A2c B2 | G2 G2A D2 |   D2 D   2 | B2 d 2    | G2    2|2 | d2  f3dfg) |   d2 (d3
# synth(samp)[ 100 ]:
#   (>|G F2Gde   / | edGc2e BF E F2 G2D F3 | A G2 AA Fd   d> d 2 |2   Bd Af|2 2 | (2 ga3B2g) | | d2 d(3
# 1700 1.21061888933
# --- Model saved to: ./irish.ckpt-1700
# (100, 95) min: 1.70573e-10 max: 0.999737 mean: 0.0105263 std: 0.0692739
# original:[ 100 ]
#  16
# K:G
# (GA) | Bdde dBAG | Bcde d2BA | Beef edBA | Beef e2e2 |
# gabg fgaf | "tr"gfed e2ge | dBAB dBAB
# synth(amax)[ 100 ]:
#  15T:D
# (3A)|| B2dB fBAF | FGdB fB d | BGed g2Bd | G2ed g2 2 |
# |2gg agaf | g2a"g2ed  2 2 | f2AF G2AF |
# synth(samp)[ 100 ]:
#  T4K:D
# B(G)|| (>eB d2AG | (ddB fc c | GBed ggg- | GGec f2f2 | ff2f b2 f | eTaoK}gd cc 2 | (gAG GGGB |
# 1800 1.19044922769
# --- Model saved to: ./irish.ckpt-1800
# (100, 95) min: 2.10774e-10 max: 0.9989 mean: 0.0105263 std: 0.069363
# original:[ 100 ]
#
# Z:transcribed by mvhplank
# K:Am
# (A/2B/2)|c>BA (Aa)>g|e>^de A2 c|B>AG Gge|(d>cB/2A/2) G2 (a/2b/2)|\
# c
# synth(amax)[ 100 ]:
#  |:Transcribed by Jee pank.K:D
#
# (G/GB/2) (2Bc ABG).g|(>dde (> (|BAAG G2e|
# dccB)AA/2) (2|(G/gg/2)|
#
# (B
# synth(samp)[ 100 ]:
#  N:Transcribed by DaypHank.K:A
#
#  GEGB/4) (Bcd (3/f.g|f2dce dc =|
# AGF G2||ddccA)AA/2)|(2((A/gg/2g|\
# ('
# 1900 1.22279720366
# --- Model saved to: ./irish.ckpt-1900
# (100, 95) min: 1.68831e-10 max: 0.999774 mean: 0.0105263 std: 0.0772653
# original:[ 100 ]
#  A|BdAF G3:|!
#
# X:354
# T:Tempest
# Z: id:dc-reel-331
# M:C
# L:1/8
# K:D Dorian
# d2cA GEE2|DEcE dEcE|d2cA GEE2|E
# synth(amax)[ 100 ]:
#   BAd  GE:|!
#
# X:12
#
# T:Shl or eZ: id:dc-reel-11
#
# M:C
# L:1/8
# K:D Morian
# ABBA BED2|G2FA EGFA|D2cA BEDD|!2
# synth(samp)[ 100 ]:
#  Fdcdc EEA|!
# AX:110
# T:Bhs rtseZ: id:dc-reel-13
#
# M:C
# L:1/8
# K:G Morian
# T-g2 BADD|G2 G GGFA|DG A BEDD|DA
# 2000 1.11602431536
# --- Model saved to: ./irish.ckpt-2000
# (100, 95) min: 1.01262e-08 max: 0.99071 mean: 0.0105263 std: 0.0628437
# original:[ 100 ]
#  A|T(BA)Bc dBGA|BA2G AcBA|
# GE2 F EDB,C|DEDB, DEGA|Bd2e dBGA|BGAF G2||
# GA|Bd2e dBGA|Bdde dcBA|Bdef gfe
# synth(amax)[ 100 ]:
#  GBBBG)(c dcAB|BGGB FGBA|
# G2E((GG2D,||D2GF  DEGA|BGgB fBGB|BGAF GE:|
# (2|BGgB fBGB|BGgB dBBA|GGgf gfed
# synth(samp)[ 100 ]:
#  BdBBG)BA dBAB|B2GB FGBA|]c2 D(G(FF,||CBD2  DEFB BGgA fBDB|cGGF EF:|
#
# dBBEBf dBAB|dAgB TBBA|Gddd g2ed
# 2100 1.14217224956
# --- Model saved to: ./irish.ckpt-2100
# (100, 95) min: 7.29089e-12 max: 0.999974 mean: 0.0105263 std: 0.0820379
# original:[ 100 ]
#  e
# T:an toirea.m.
# R:air
# N:"Moderate." "Collected from J. O'Neill."
# B:O'Neill's 619
# Z:"dcde" should pr
# synth(amax)[ 100 ]:
#   N: n ta n  .c
# Z:air
# N:"Moderate"" "Collected brom J. O'Neill."
# Z:O'Neill's 558
# Z:TTrrlm "iourd bro
# synth(samp)[ 100 ]:
#  rd:Kn tonnns.dl
# M:air
# N:"Voderate"" "Collected hrom F. O'Neill."
# N:O'Neill's 513
# Z:TTrLldM"counl bao
# 2200 1.14663257241
# --- Model saved to: ./irish.ckpt-2200
# (100, 95) min: 1.41247e-10 max: 0.999871 mean: 0.0105263 std: 0.0760715
# original:[ 100 ]
#  EDEF GFGA|BBgB fBec|dcde dBAF|DFAF FEE:|!
#
# X:127
# T:Gooseberry Bush
# Z: id:dc-reel-117
# M:C
# L:1/8
# K:D M
# synth(amax)[ 100 ]:
#   || G2GA|BdAB dBAd|dBBB fBAF|!FAF DAD:|!
#
# X:27
#
# T:Terneror y
# Brrh
# Z: id:dc-jeel-25
#
# M:C
# L:1/8
# K:D Ma
# synth(samp)[ 100 ]:
#  ) ||GAG2|BdeB GBge|dcBB acAF|BBGG GED2|!
# AX:211
# T:Yrune or'y
# Lir
# Z: id:dc-jeel-37
#
# M:C
# L:1/8
# K:D Ma
# 2300 1.074149189
# --- Model saved to: ./irish.ckpt-2300
# (100, 95) min: 9.63753e-10 max: 0.993396 mean: 0.0105263 std: 0.0689607
# original:[ 100 ]
#  d eAAc | B>G (3GGG BcdB | dega bg g2 :|
# a | bgfg   (eg)(dg) | cBcd eAAg | bgfg      egdg | egfa bgga
# synth(amax)[ 100 ]:
#   bfA || BGGB(3GGG (GdB | cefa bga(2 ||
# |2| bgag aa ag)(fg) | eAAd efcc | fgag ea    ddg   edda ggaf
# synth(samp)[ 100 ]:
#   bfB| | B3ABB3GGG GGd^ | Aefagbgae2 ||
# |>|  aag ea aa (fg) | (AdA  fcf | Tabg ea    ddB   adfa gaef
# 2400 1.09510812461
# --- Model saved to: ./irish.ckpt-2400
# (100, 95) min: 4.55936e-12 max: 0.999973 mean: 0.0105263 std: 0.087693
# original:[ 100 ]
#   HEART BOWED DOWN
# B: O'Neill's 499
# Z: 1999 by John Chambers <jc@trillian.mit.edu>
# N: "Slow"
# N: Colle
# synth(amax)[ 100 ]:
#  |a2,
# MOAREE
# TORE
# B: O'Neill's 343
# N:T1999 by John Chambers <jc@trillian.mit.edu>
# N: "Slow
# N:I"ollec
# synth(samp)[ 100 ]:
#  Ana
# ILNRA  OHCE
# N: O'Neill's 323
# Z:T1999bby John Chambers <jc@trillian.mit.edu>
# N: "Clow.
# N:ICollec
# 2500 1.08060620546
# --- Model saved to: ./irish.ckpt-2500
# (100, 95) min: 4.1472e-10 max: 0.999582 mean: 0.0105263 std: 0.0731581
# original:[ 100 ]
#  g edB|c2A BGD|G3 BdB|BAG ABd|!
# efg edB|c2A BGD|G3 BdB|AGF G2:|!
# D|GBd g3|agf g2e|fed edB|c2A BGD|!
# G
# synth(amax)[ 100 ]:
#   |aB|AA  AAE|G3 G2B|AAG ABc|!
# efg adB|dBA AAE|G3 GdB|AGF G2:|!
#
# |GBd gd|agf gfe|fed cdB|AAA AGE|!
# GB
# synth(samp)[ 100 ]:
#   MgB !B 2AGE|GB G a|!eG A2G|!
# efg acB|A2c AAB|GE AdB|AFF G2:|!
# B|G2d dd abf ge |fed c3B|ABG F2E|!
# E3
# 2600 1.03204951704
# --- Model saved to: ./irish.ckpt-2600
# (100, 95) min: 1.07303e-09 max: 0.993449 mean: 0.0105263 std: 0.0751007
# original:[ 100 ]
#  edB|GBAFG2||
# (ef)|gfga gede|gabg ageg|{b}agab agef|gabge2de|
# gfga gede|gabg agef|gfga gedB|GBAFG2||
#
# synth(amax)[ 100 ]:
#  d  c2d  2||
#
# Bf)|gfga gedB|gebg agef|db}agfg agef|gegg 2|2|
# ffga gedB|gebg agef|gega gedB|c2dG 2||
#
#
# synth(samp)[ 100 ]:
#     c2d  E:|
# Bef)|a2ga gedB|gegg agfc|^a}a^ag agef|gfb( 2(c|
# dfga gede|bagg f=ef|gbed gedB|G4GG 2(|
#
#
# 2700 1.05803119421
# --- Model saved to: ./irish.ckpt-2700
# (100, 95) min: 8.56743e-09 max: 0.989678 mean: 0.0105263 std: 0.0613411
# original:[ 100 ]
#  /2F/2)|
# .G(FG)|(~edB)|A3-|A2d|
# (edB)|(GAB)|(EGc)|(e2f/2e/2)|
# (dBG)|(AEF)|G3-|G2||
# d|ede|(~gfe)|fed|(
# synth(amax)[ 100 ]:
#  8)/2) ((G(BGA (AAcc) (2 A|2(|
# (e>))|(cAB)|(d2A) (edd)2g/2)|
# dd>A) (ABF) (4 |G2||
#
# |gfBfffffe)|(ed ec
# synth(samp)[ 100 ]:
#  ))/2) z.G(.GA .FAfBc {3 A
# 2F|
# |ca{)|dBEAd|(cEA).fedd22e/2)|
# dacG)|(dBF) A4G2(2||
#
# |gacf(ggfe) f>f (f
# 2800 1.03616319954
# --- Model saved to: ./irish.ckpt-2800
# (100, 95) min: 5.21315e-10 max: 0.995513 mean: 0.0105263 std: 0.0710404
# original:[ 100 ]
#  : (FGF)  F2 D  G2 E | (FGF) F2 D E2 D | (FGF)  F2 D  G2 B | (AFD) D2 F E2 D :|
# |: (BcB) (BAG) (FGA)
# synth(amax)[ 100 ]:
#  113/)) | 2 D2||2   | DFG)) G2 D |F D |
# D3G)) G 2 D | 2   | AAG)) D2   |2   ||
# |: A3c))  AA))  BD)) |
# synth(samp)[ 100 ]:
#   I3/)) ||> DF\|2  2  2DdAE G2 (2|2 D |
# E3G)) GD2 D       : A3B)) B2   |2 (2||
# |   f>))  {GGF |dDA) |
# 2900 0.989143885374
# --- Model saved to: ./irish.ckpt-2900
# (100, 95) min: 1.35189e-10 max: 0.997698 mean: 0.0105263 std: 0.0752009
# original:[ 100 ]
#
# K:D
# (d/B/)|ADD F2d|cAA BAG|FDD A2d|cAF GAG|
# FED def|ged cd(e/g/)|fed cAF|GFD D2:|
# (d/B/)|ABA fed|eA
# synth(amax)[ 100 ]:
#  M:D
# (d/e/)|AFD DDD|eBG AGG|ADD DF |cAG G2B|
# FDF G2f|gfc cAee/f/)|fdd cAF|GEG D2:|
#
# f/e/)|AFA Aed|ccA
# synth(samp)[ 100 ]:
#  N:E
# (A/c/) AAF DAD|e2B BAG|ADF FFg|cAF F2B|
# FEF {=f|{fd c2ee/f/)|ddd cAg|cAD G2:|
#
# e/e/)|"Dd dAd|ecB
# 3000 1.02466350138
# --- Model saved to: ./irish.ckpt-3000
# (100, 95) min: 7.53009e-12 max: 0.999964 mean: 0.0105263 std: 0.0861235
# original:[ 100 ]
#  T: One Sunday After Mass
# B: O'Neill's 231
# N: "Slow"
# N: "Collected by J.O'Neill"
# Z: 1997 by John Cham
# synth(amax)[ 100 ]:
#  : T'  ttid y
# Bnoer
# ters
# Z: O'Neill's 33"
# N: "Mlow"
# N: "Collected by J.O'Neill"
# K: 1997 by John Chamb
# synth(samp)[ 100 ]:
#  :TE'  Hpmdli
# Nneer
# tant
# Z: O'Neill's 653
# N: TWlow"
# N: "Mollected by J. 'Neill"
# K: 1997 by John Chamb
# 3100 0.990508889556
# --- Model saved to: ./irish.ckpt-3100
# (100, 95) min: 1.60496e-10 max: 0.9999 mean: 0.0105263 std: 0.0781441
# original:[ 100 ]
#  p.org"
# K:D
#    ((3ABc) | dcde  dAFA | Bcde dcBA | BGGB AFdF | EFGA GFED |
#              dcde  fdAF | E
# synth(amax)[ 100 ]:
#  ierg"
# K:G
# (  (A3ABc) | d>de d cGA | dddB dcBA | GcAB A2DF | D2GE B2ED |
#               2de   dcG | GA
# synth(samp)[ 100 ]:
#  }lrg"
# K:G
# G  A~3ABc) | f>dA d gFA | ddde fedA | GGEB A2Ec | DBGc,G2ED |
# d B      B  GDgdA dfggG | GA
# 3200 0.954427150488
# --- Model saved to: ./irish.ckpt-3200
# (100, 95) min: 3.06492e-11 max: 0.999951 mean: 0.0105263 std: 0.0768261
# original:[ 100 ]
#  ig
# L:1/8
# K:G
# G/F/ | D2G G2A | BdB ({d}c)AG | F2D DED | F2G AFD |
# D2G G2A | BAG ABd | fed ({d}c)AF |
# synth(amax)[ 100 ]:
#  lhM:1/8
# K:D
# G A/ | EE  G2A | BcB cAd}c)AG | AGD DED | ADD AFD |
# |EG G2A | BcG BBc | eed cce}c)AG | G
# synth(samp)[ 100 ]:
#  thK:1/8
# K:D
# D 2/ | EE( G2A | BGd {c=}c)A^ | E2D DFD | TDD AGD | AEG GBA | AcB BEc | fed cde}cBAF | E
# 3300 1.00245157659
# --- Model saved to: ./irish.ckpt-3300
# (100, 95) min: 2.91207e-10 max: 0.999388 mean: 0.0105263 std: 0.0716568
# original:[ 100 ]
#  dz {c}d2 (e/d/B) | dz {c}d2 (d/e/f) | gz {f}">"g2 (ag) | fz ">"f2 gf \
# | {^d}e4 (=dB) | {^c}d4 (Bd/e
# synth(amax)[ 100 ]:
#    ed}B2 dd/f/c/ | c2 ed}B2 BB/e/f/ | g2 (a}(e"d2 |e/) | f2 (>"d2 (2 |
# | eac}ef (dcB) | (dc}d2 (dd/e/
# synth(samp)[ 100 ]:
#  a|ed}B3 Ad/2/c/|| c  Bd}B  zB///)/ | d2 \f}( "e>d"fgf | ae ei"g> e2 |
# | (ad}e4 ddfe) | ccc}dc eddee/
# 3400 0.937227054238
# --- Model saved to: ./irish.ckpt-3400
# (100, 95) min: 1.19654e-10 max: 0.999684 mean: 0.0105263 std: 0.070952
# original:[ 100 ]
#  ed|cBABc2dc|BGBG cBAG|FGAF D2 Bc|
# |dcBc d2 ed|cBABc2 dc|BgGB AcFA|D2G2G2:|
#
# X: 1631
# T:The Rose of Dr
# synth(amax)[ 100 ]:
#  d cAA  2|2|BGAd AAAG|FGAF G2|(-|
# ddgdA d2 (f|cAAB 2 (2|BGdB GGBA|G2 2 2 |
#
# X:11355
# T:The Meae of tri
# synth(samp)[ 100 ]:
#  d^
# AcG 2|(|AGAG AeAG|FAAF G2|D-:
# d edA Ag Ad|cAAB d dA|BGfd A2Ac|D2 F 2||
# AX:19324
# T:Ghe Mocs tr Pro
# 3500 0.933902446032
# --- Model saved to: ./irish.ckpt-3500
# (100, 95) min: 1.33749e-10 max: 0.999168 mean: 0.0105263 std: 0.0747164
# original:[ 100 ]
#   DED  D2   :|
# |: d | dfa afd  | gbg faf | dfa afd | cee  e2 f  |
#        dfa afd  | gbg faf | BdB AFA
# synth(amax)[ 100 ]:
#  |2F ||E    |
#
# : ( | d2d  fd || cfg faf | gfa afd | cee eec d ||         ca  fd || ffg fef | fdB ABA
# synth(samp)[ 100 ]:
#  gAF G|E D:|
#
# : B \ e2f afd || gfg ffg | gea agd | fde  dg d || e       ca  gd || ceg  ef | ddc BFA
# 3600 0.973296185136
# --- Model saved to: ./irish.ckpt-3600
# (100, 95) min: 3.38172e-11 max: 0.999971 mean: 0.0105263 std: 0.0807211
# original:[ 100 ]
#  3
# T:Connie Walsh's
# Z: id:dc-slide-7
# M:6/8
# L:1/8
# K:D Major
# d3|Bcd Bcd|c2B A2A|Bcd e2f|g3 f2g|!
# agf gf
# synth(amax)[ 100 ]:
#   Z:Bonnee tisshes
# Z: id:dc-rlipe-1
# M:6/8
# L:1/8
# K:D Major
# A|ceAd e2d|cAA ABG|Bcd e2f|g3 g2e|!
# fgf gfe
# synth(samp)[ 100 ]:
#  DB:Ealnee Poilt's Z: id:dc-hlipe-2
# Z:6/8
# L:1/8
# K:D Major
# AB FAd B2A|eAA A2F|=2d edd|g2 g3d!!
# fgf g2e
# 3700 0.889617574215
# --- Model saved to: ./irish.ckpt-3700
# (100, 95) min: 6.31375e-13 max: 0.999968 mean: 0.0105263 std: 0.0830583
# original:[ 100 ]
#
# N:"Collected from Early"
# R:Hornpipe
# B:O'Neill's 1558
# M:2/4
# K:G
# B>c|d>de>d B2c>A|"~"G>GA>F G2B>c|d>g
# synth(amax)[ 100 ]:
#  M:"collected brom Fnrly"
# B:sornpipe
# B:O'Neill's 1499
# Z:C/4
# K:G
# (2A|dBBc>f B>A>A|B>"G>AA>F G2 >c|d>ef
# synth(samp)[ 100 ]:
#  M:"collected brom Cnrly"
# B:sornpipe
# B:O'Neill's 14j7
# N:C/4
# Z:Dmg2cd(2gc>d B2c>d|d>"E3FA>FDGAF>c|d>e
# 3800 0.91483346343
# --- Model saved to: ./irish.ckpt-3800
# (100, 95) min: 1.33876e-12 max: 0.999977 mean: 0.0105263 std: 0.0937158
# original:[ 100 ]
#  lan
# B:O'Neill's 638
# Z: 1997 by John Chambers <jc@trillian.mit.edu>
# N:"Spirited"
# M:6/8
# L:1/8
# K:D
# A \
#
# synth(amax)[ 100 ]:
#  lndB:O'Neill's 518
# Z:T1997 by John Chambers <jc@trillian.mit.edu>
# N: Spirited"
# N:6/8
# L:1/8
# K:D
# ( \
# |
# synth(samp)[ 100 ]:
#  l.tM:O'Neill's 413
# N:T1997 by John Chambers <jc@trillian.mit.edu>
# M: Bpirited" M:3/8
# L:1/8
# K:D
# ( \
# |
# 3900 0.927162157893
# --- Model saved to: ./irish.ckpt-3900
# (100, 95) min: 1.74803e-11 max: 0.999759 mean: 0.0105263 std: 0.073742
# original:[ 100 ]
#   acec|fcec B2cB|!
# AFEF A3e|fece faaf|ecc2 acec|BAGB A2:|!
# ed|ceAe ceAc|BEE2 BcdB|BAAG Acec|BEE2 BcdB
# synth(amax)[ 100 ]:
#  |gA||Badc BAcB|A
# ABDF ABB|fede feef|ecB2 accc|BABB A2:|!
#
# f|cAee cAAe|BAE2 Bcde|AdGB ABBd|dAE2 BcdB|
# synth(samp)[ 100 ]:
#  9bef|aaac BAce|A
# cBFF D2B|dede fgef|edd2 acgc|cAGB Ac:|!
# eg|cAAe fAAe|eAEG Bcde|AAGG A2ed|dAGD G:de|
# 4000 0.859200800657
# --- Model saved to: ./irish.ckpt-4000
# (100, 95) min: 6.16123e-11 max: 0.999763 mean: 0.0105263 std: 0.0774543
# original:[ 100 ]
#   g2 ga|
#   ((3bag) af ((3agf) fd|((3efg) dc (TBA) A2|{A}GFGA (Bd) d2|((3efg) ((3fga) g2|]
#
# X:1429
# T:T
# synth(amax)[ 100 ]:
#  |f e  bb  b3bag) ag g33ggf) (d|e(3efg) dB BBBA)GA2|(c}BEGA BBG)dd2||A3efg) dd3fga) ee ]
#
# X:1311
# T:Th
# synth(samp)[ 100 ]:
#  Te g/
# bbbb3bag) ag g~3ggf) d>|((3cfg) (B B3Bc)AB2|(g}dFGA (BA) dB |A3ef)) d33aea) ce ]
#
# X:1719
# T:Th
# 4100 0.889499551654
# --- Model saved to: ./irish.ckpt-4100
# (100, 95) min: 8.45529e-11 max: 0.998787 mean: 0.0105263 std: 0.0757168
# original:[ 100 ]
#   d2 (e/2f/2) | gf(e/2d/2) Bd (3fed | (e3 e2) (3d/2e/2f/2 |
# g2 (ef)(ge) dG (A/2G/2) | EDD D2 (G/2B/2)
# synth(amax)[ 100 ]:
#  |2 (cdff/2) | g2ee/2d/2) B2 |eeed | BBA d)) (ddeee/2 /2 |
# g2 (g// ge) |2 |G/GG/2F | (2D D2 (G/2B/2)
# synth(samp)[ 100 ]:
#  igBcc/df/2g | g>ee/2d/2) B2)|c./d | BB= =)) (fAece/4 /2d|
# |2 (ecg .b) |= (3GBB/2F | G3D "E EG/2B/2)
# 4200 0.872952516079
# --- Model saved to: ./irish.ckpt-4200
# (100, 95) min: 1.57687e-10 max: 0.999511 mean: 0.0105263 std: 0.0749274
# original:[ 100 ]
#   F2|!
# A>B cA|BA ce|A>B AF|FE E2:|!
# e>f ec|BA Bc|e>f ec|BA F2|!
# e>f ec|BA Bc|A>B AF|FE E2:|!
#
# X:8
# T:B
# synth(amax)[ 100 ]:
#  |E |
# DGB c>|dd BB|d>B c>|EE E2:|!
#
# af gc|BA Bc|ddf gd|BA A2:!
# eff ec|BA Bc|d2B AF|EE E2:|!
#
# X:1
# T:Br
# synth(samp)[ 100 ]:
#  eE|G
# g>B c>|dE Ae d>f c>|EE G2:|!
#
# af g2|B2 ee|ddf gd|BA A2|!
# Aef ec|BA Bc|B>edc2|EA E2:|!
#
# X:13T:Al
# 4300 0.834196764231
# --- Model saved to: ./irish.ckpt-4300
# (100, 95) min: 7.44363e-11 max: 0.999656 mean: 0.0105263 std: 0.0797609
# original:[ 100 ]
#  (3FED AD (3FED | E^DEF GFGA |1 Beef gfed :|2 Bee^de2 ||
# (ef) | gfga bgeg | fefg afdf | gfga bgeg | f
# synth(amax)[ 100 ]:
#  3dED AD (3FED | AFDEF GFEA |  Bee^ efed ||2 eee^d 2 |
#
#
# ef) | gfga bgeg | fddg afdf | gfea bgeg | fd
# synth(samp)[ 100 ]:
#  eBED GGF(3(ED||
# EeFE> GFEA |1 (Ge^ eeez ||2 (ee^d 2 |
#
# (ef) | gfea ggaf | fcdg afdf | gfga bgag | fd
# 4400 0.865013481379
# --- Model saved to: ./irish.ckpt-4400
# (100, 95) min: 7.29843e-11 max: 0.999567 mean: 0.0105263 std: 0.0794886
# original:[ 100 ]
#  G G2 ||
# (B/c/) | .d(e/d/B/A/) GBd (e3/2g/f/e/) | .d(e/d/B/A/) G(dB) (A3/2c/B/A/) |
# (GA/G/E/D/) D(dc)
# synth(amax)[ 100 ]:
#   A2 ||
#
# Bcc/) \ dd.d/d/)/A/) .2d |ed/2d/f/e/) | dd(d/d/B/A/) .2B// |AF/2c/4/A/) | |G>BB/E/D/) (GB/)
# synth(samp)[ 100 ]:
#  FA2B>
#
# dcA/) \ dd.d/^/)/A/)..2d |ef/2d/f))/).| (d(d/d/B/A/) d2Ad) \AG/2^/B/)/) \ |G.BB/E/D/) .Gdc)
# 4500 0.846761271954
# --- Model saved to: ./irish.ckpt-4500
# (100, 95) min: 4.59552e-11 max: 0.999478 mean: 0.0105263 std: 0.0805535
# original:[ 100 ]
#  2:|!
# (3efg|a2ab ageg|agab a2ge|dega gedc|B2G2 G2|!
# [1 (3efg|a2ab ageg|agab a2ge|dega gedB|c2A2 A2:|!
# synth(amax)[ 100 ]:
#   |
#
#
# 3Afg|a2ab a2eg|a2ab a2ga|dgga bedB|B2G2 G2:|
# [1 d3dfg|a2ab ageg|a2bb a2ga|dBga bedc|!AA2 A2:|!
#
# synth(samp)[ 100 ]:
#  d|!
# E3Afg ae b acfd|afaf agga|dBga gfdB|BAB2 G2:]
# [2 d3efg|aeGc a3eg|dbbg agge|a2da gadB|AAA2 A2:|!
#
# 4600 0.802683446407
# --- Model saved to: ./irish.ckpt-4600
# (100, 95) min: 4.67387e-12 max: 0.999974 mean: 0.0105263 std: 0.0779095
# original:[ 100 ]
#  agf ged cAG |
# (A<d)d d2 e f2 f | Add ded cAG | dcA cde f2 g | agf ged cAG |]
#
# X:1118
# T:Swaggering Ji
# synth(amax)[ 100 ]:
#  n  |fd |AG | |d<d)d d2 e f2 d | gdd dcd cAG | AeA Gde f2 g | aff ged cAG |
#
# X:1446
# T:Taesgering Wig
# synth(samp)[ 100 ]:
#   | |2cB|AG | AfGd)g de e f2 d e dcd ccd cAG | T<A Gde f2 a | acf bfd cAG :
#
# X:9124
# T:Ttokgering tog
# 4700 0.850705032349
# --- Model saved to: ./irish.ckpt-4700
# (100, 95) min: 6.83628e-10 max: 0.999351 mean: 0.0105263 std: 0.0741521
# original:[ 100 ]
#  G B)(c/d/) (c>A) | (F>A) "p"G2- G ((3d/e/f/) | ">"g2 (e>g) (f>d) | (ec) d2- d ((3d/e/f/) |
# | ">"g2 e
# synth(amax)[ 100 ]:
#   GG|A/B/)|ee/A)|| GF>G) (p"(2  G ((3B/e/f/) |
# g>"g2 (f/f) (f<d) | (g>) (2  d |c3e/e/f/) |
# | g>"g2 (
# synth(samp)[ 100 ]:
#  |B2(d/B/e(BeeA) | GA>E) Gtr{FG G|z(3B/e/f/) | g>"g2 "b>f) (A<d) | (c>  (2 de |e3e/2/d/) |
# ggg>"g2 "2
# 4800 0.819964932799
# --- Model saved to: ./irish.ckpt-4800
# (100, 95) min: 2.99441e-11 max: 0.998331 mean: 0.0105263 std: 0.0753766
# original:[ 100 ]
#  :  (ga)  |    b2    b2   bagf | e2 ee e2 fg |   a2   aa  (ab)ag | f2 dd d2 ef|
#                    gf
# synth(amax)[ 100 ]:
#  11 3a) |  b   2 g   2    2gf | ed e2 e2 e2 |
# a  f a  2   ag)ag | fd d2 d2  f
# g                   bg
# synth(samp)[ 100 ]:
#  |1r2a) || b   g   g 2    2g2 | ed eA f2 eg | e a2 (  g   bg)ag | fd de d2 gf
# g g      A gfg    dg2g
# 4900 0.791768085361
# --- Model saved to: ./irish.ckpt-4900
# (100, 95) min: 4.48891e-13 max: 0.999998 mean: 0.0105263 std: 0.0927369
# original:[ 100 ]
#  catter the Mud
# N:"2nd Setting"
# N:"Collected by McFadden"
# B:O'Neill's 967
# Z:Transcribed by Dan G. Pet
# synth(amax)[ 100 ]:
#   lter the Cos
# N:"Cnd Setting"
# N:"Collected by FcFadden"
# B:O'Neill's 877
# Z:Transcribed by Dan G. Pete
# synth(samp)[ 100 ]:
#  tl.ek Bo  Var
# N:"Cnd setting"
# B:"Collected by CcFadden"
# B:O'Neill's 857
# Z:Transcribed by Dan G. Pete
# 5000 0.837597597837
# --- Model saved to: ./irish.ckpt-5000
# (100, 95) min: 7.99585e-13 max: 0.999976 mean: 0.0105263 std: 0.0754064
# original:[ 100 ]
#  EFGAB>d)|e2He2 (3cBA|(G4 F2)|E4||
#
# X:131
# T:A Soldier Tonight Is Our Guest
# N:"With spirit"
# B:O'Neill'
# synth(amax)[ 100 ]:
#       c  d2 e2 eedBA|!33 F2)|E2||
#
# X: 58
# T:T Bandier th ight Ni Dud Tue
# t Z:"Sith fpirit" N:O'Neill's
# synth(samp)[ 100 ]:
#  3G Bdc| =2ae2 e3(AA|!3< F2)|A4||
# zX:562
# T:GNCpndie  tasinht Ms Mnt Roels
# Z:"Mith fpirit"
# N:O'Neill's
# 5100 0.785108057857
# --- Model saved to: ./irish.ckpt-5100
# (100, 95) min: 1.36605e-13 max: 0.999997 mean: 0.0105263 std: 0.0861
# original:[ 100 ]
#  cd2c-d | efgedBGA | B2AAA2 :|
#
# X:1677
# T:Julia's Wedding
# M:4/4
# L:1/8
# B:O'Neill's 1677
# N:"collected by
# synth(amax)[ 100 ]:
#  Ae Ac | efgedBGA | B2A2 2 :|
# |X:1657
# T:Tocians Helding
# M:C/4
# L:1/8
# B:O'Neill's 1680
# N:"collected by
# synth(samp)[ 100 ]:
#  Ae Bd |]efgad2GB | BA 2A2(:|
# |X:1817
# T:Tenians Gelding,R:4/4
# L:1/8
# B:O'Neill's 1869
# N:"collected by
# 5200 0.774621834159
# --- Model saved to: ./irish.ckpt-5200
# (100, 95) min: 3.19159e-13 max: 0.999963 mean: 0.0105263 std: 0.0778246
# original:[ 100 ]
#   e2 d|cBA c2 A|dBA A2 e|\
# fgf fed|efe efg|aba gec|edc d2|]
#
# X:798
# T:Courtney's Favorite.
# C:Carberry.
# synth(amax)[ 100 ]:
#  |2 (2cAA Ad d|GcG A2:d|
#
# fga fed|ede edg|fga gfc|ddc d2:|
#
# X:168
# T:Pomnt ey s Navorite
#
# C:Frreyrry.
#
# synth(samp)[ 100 ]:
#  cfedB
# AA Ac B|\eG AF:d|\
# fea fgd|edd e2g|ffa gec|ddc dz:|
#
# X:959
# T:Dolrneeo s Navorite
#
# T:Crreerty.
#
# 5300 0.810008488297
# --- Model saved to: ./irish.ckpt-5300
# (100, 95) min: 6.28183e-12 max: 0.9992 mean: 0.0105263 std: 0.07332
# original:[ 100 ]
#  (G>AG).F (D>CD).F | G2 G>-A B3 c |
# (d>ed).c B2 A>-B | (GBAG) F2 D-F | (G>AG).F (D>CD).F | G2 G>A G3
# synth(amax)[ 100 ]:
#  3FA)) G |3EED)|F|| G2 (2GG B2 c |
# d3>e)) c (> AFGB | c3>AG) F2 (2E | (GAAG) F (D>ED).F | G2 (2G G2 |
# synth(samp)[ 100 ]:
#  (/A))|E|(3EED).A|| d> (-AG B> A |
# |32g)) e (2 a>GB | cc3)G) (E DFB | (GBAG)FE (DDED).F | (2 e2A B2 z
# 5400 0.745315788984
# --- Model saved to: ./irish.ckpt-5400
# (100, 95) min: 1.736e-12 max: 0.999703 mean: 0.0105263 std: 0.081039
# original:[ 100 ]
#   | D2 D2 DFAF | dFAF dFAF | E2 (EF) GBEB | edcB AGFE |
#  D2 D2 DFAF | dFAF GFED | DFAg faec | d2 d2 d
# synth(amax)[ 100 ]:
#  | A2 (2 D2AF | D2AF  FAF | E2 (EF) GBAB | A2BB A2FE |
#   2 (2 D2AF | d2AF dFED | F2Ad fdec | d2 (2 d2
# synth(samp)[ 100 ]:
#  | (E D2 D2A    D2AF dFAG | BGBBDF) AFAc | c2cB AGFA |   2 (2 DFAF | d2AF GBGD | F2Ad fdec   d2 (2 d2
# 5500 0.766512299776
# --- Model saved to: ./irish.ckpt-5500
# (100, 95) min: 1.17415e-14 max: 0.999998 mean: 0.0105263 std: 0.0880659
# original:[ 100 ]
#   E3 (EFA) | B2d c2B | BAA A2 ||
#
# X:677
# T:Planxty Irwin
# C:O'Carolan
# B:O'Neill's 677
# Z: 1997 by John C
# synth(amax)[ 100 ]:
#  |2 EG/)) |
# B2  (2  | A2G A2 ||
#
# X:411
# T:Planxty Ordin
# M:O'Carolan
# B:O'Neill's 663
# Z: 1997 by John Ch
# synth(samp)[ 100 ]:
#  |2Faf/)) |
# B2d2(d  |
# AAG A2  |
#
# X:464
# T:Ilanxty oimip
# N:O'Narolan
# B:O'Neill's 635
# Z: 1997 by John Ch
# 5600 0.779808052778
# --- Model saved to: ./irish.ckpt-5600
# (100, 95) min: 1.20524e-11 max: 0.999932 mean: 0.0105263 std: 0.079501
# original:[ 100 ]
#  G AGEG|ADD2 EDEF|G2AG EGGB|!
# ADD2 D3G|AcBG AGEG|c3A B2BA|GBAG EGG:|!
# B|d2Bd edBd|dedB AGEG|d2Bd edBA
# synth(amax)[ 100 ]:
#   ABGD|DDD2 AGEG|GABG EGD2|A
# AGD2 A2B|AGBG AGEG|D2A BAGA|GAAG EGG:|!
# B|d2Bd edBA|e2dB AGEG|D2Bd edBA|
# synth(samp)[ 100 ]:
#   F3ED|D3D2 AcEG|GAAG EGD:|A
# ADD2 FEA|AGBA AGEG|A2B B2EA|GFAG EFg:|!
# A|dBBd edB2|eedB A2EG|c2Ad edBA|
# 5700 0.723912587166
# --- Model saved to: ./irish.ckpt-5700
# (100, 95) min: 5.13429e-14 max: 0.99999 mean: 0.0105263 std: 0.0834382
# original:[ 100 ]
#  2 ef g2 a2 | gefd e2 (dB) | d2 ef g2 a2 | gefd (~BA) A2 |]
#
# X:1468
# T:Molly Malone
# M:C|
# L:1/8
# N:"coll
# synth(amax)[ 100 ]:
#   ( g|2 f2 | e2fd ec (dc) | A2 ef g2 a2 | gefd eBBA) A2 |
#
#
# X:1422
# T:Toll  Malone
# R:C|
# L:1/8
# R:"colle
# synth(samp)[ 100 ]:
#  T. g|b f2 | bffd e2 afB)|| A2 e^ g2 a2 | gffd =BBA) A2 |
#
# BX:1269
# T:Torl  PaconeyM:C|
# L:1/8
# N:"colle
# 5800 0.754284533858
# --- Model saved to: ./irish.ckpt-5800
# (100, 95) min: 3.66721e-16 max: 1.0 mean: 0.0105263 std: 0.0919152
# original:[ 100 ]
#  ."
# B:O'Neill's 583
# Z:transcribed by J.B. Walsh, walsh@math.ubc.ca
# M:6/8
# L:1/8
# %Q:100
# K:Gm
# G|B>cd cBG
# synth(amax)[ 100 ]:
#  d
# Z:O'Neill's 547
# N:Transcribed by J.B. Walsh  walsh@math.ubc.ca
# M:6/8
# L:1/8
# %Q:110
# K:G
#
# D|F2cB dBc|
# synth(samp)[ 100 ]:
#
#
# Z:O'Neill's 339
# N:Transcribed by JoB. Walsh
#  walsh@math.ubc.ca
# M:9/8
# L:1/8
# %Q:100
# K:C
#
# (>(2cB cAc|
# 5900 0.745698727965
# --- Model saved to: ./irish.ckpt-5900
# (100, 95) min: 1.59555e-15 max: 1.0 mean: 0.0105263 std: 0.0838464
# original:[ 100 ]
#  afef d2|]!
#
# X:36
# T:Charlie Harris's No. 2
# Z: id:dc-reel-35
# M:C
# L:1/8
# K:D Major
# B|A3B AFF2|AFAd f3g|a
# synth(amax)[ 100 ]:
#  nd| dBe]!
#
# X:1
#
# T:Caarlie Carris's
# No. 2
# Z: id:dc-jeel-22
# M:C
# L:1/8
# K:D Major
# F|A3B AFF2|ABcB f3g|af
# synth(samp)[ 100 ]:
#  gff|.Bd
# !
#
# X:14
# T:Poarlie Girris's Ro. 1
# Z: id:dc-reel-537M:C
# K:1/8
# K:A Dajor
# F|A3G AFD2|DBcc fde|ag
# 6000 0.709065269828
# --- Model saved to: ./irish.ckpt-6000
# (100, 95) min: 1.47799e-12 max: 0.999548 mean: 0.0105263 std: 0.0753937
# original:[ 100 ]
#  EFAc dfaf|ecBA FAA2||
# ceecd2(fd)|ceec BAFA|ceecd2(fd)|ecBA FAA2|
# ceecd2(fd)|ceec BAFA|cefg abaf|edcB
# synth(amax)[ 100 ]:
#      |2af|gcBc BAA2||
#
# eec 2(fd)|eeec BAFA|ceef 2(dd)|ecBA BAA2||feec 2(dd)|eeec BAFA|ceee afaf|eccB
# synth(samp)[ 100 ]:
#  2 |A|2ef gcAc dEF2:|
#
# eec 2cfd)|eeec BABA|cefe 2(ed)|ecBd GAA2||feaa 2z~d/|eecc BeGA|cBeg abaf|edcB
# 6100 0.738008300662
# --- Model saved to: ./irish.ckpt-6100
# (100, 95) min: 1.99372e-11 max: 0.999302 mean: 0.0105263 std: 0.0781228
# original:[ 100 ]
#
# d2 g2 (g>a) | b2 d2 "#"~d2 | e2 e>g f>e | d4 ||
# B>c | d2 d2 (d>f) | g2 (dg/a/) bg | d2 B>c d>c | B2
# synth(amax)[ 100 ]:
#  |c (d fg>e) f b2 g2 (>"cc2 | d3 (2f f2e | d4 ||
# |>c | d2 d> dc>e) | e2 (f>)a/) (g | g2 (2G d2c | B2
# synth(samp)[ 100 ]:
#  RB((y df>a) f b2 g2 (>"cf2 | d2 d2f g2e | d4 B
# |2c | d2 b> ed>e) | e4 (d>/2/) g2 | (2 G2G d2c | B3
# 6200 0.717140539289
# --- Model saved to: ./irish.ckpt-6200
# (100, 95) min: 1.23912e-12 max: 0.999835 mean: 0.0105263 std: 0.0851371
# original:[ 100 ]
#  DBc|dBA GFG|!
# AFD DBc|dfd ece|fdf gec|Adc d2:|!
# f|agf gag|fdf ecA|agf gag|fdf efg|!
# agf gag|fdf ece|
# synth(amax)[ 100 ]:
#  E, dBcFAEG|A
# AFD DFc|ded ecA|fdf gec|Adc d2:|!
#
# |aff gfg|fdf ecA|agf gag|fdf efg|!
# agf gag|fdf ecA|f
# synth(samp)[ 100 ]:
#  4dddBfGABG|A
# ABD DFc|dfd egA|ddf gec|Adc d2:|!
#
# |a2f gfg|fdfegcA|Acf gag|fdf edg|
#
# Bff gaf|fdf acA|a
# 6300 0.684395669699
# --- Model saved to: ./irish.ckpt-6300
# (100, 95) min: 1.17202e-12 max: 0.999892 mean: 0.0105263 std: 0.0838052
# original:[ 100 ]
#  "E2 :|
# d | g>dg gag fed | efe efg a2 b | gdg gag fed | gfe dcB A2 d |
# g>dg gag fed | efe efg a2 g/a/
# synth(amax)[ 100 ]:
#
# n "|
#
# || gffg gag |ed | gfg efg a2 b | gdB gdg fed | gfg dcB AG G |
# gdag gag fed | gfg efg af g a/
# synth(samp)[ 100 ]:
#
# nbD|
# g|| g2de gaf |ed | gfg fdg a2 b | gegegdg f=d | cfe dcB gG G |
# edfg gag fed | gfe edg af g a/
# 6400 0.725709233284
# --- Model saved to: ./irish.ckpt-6400
# (100, 95) min: 1.55027e-14 max: 0.999997 mean: 0.0105263 std: 0.0945005
# original:[ 100 ]
#  ohn Chambers <jc@trillian.mit.edu>
# N: "With spirit and feeling"
# N: "Collected by J.O'Neill"
# K:C
# (D>E
# synth(amax)[ 100 ]:
#  rn Chambers <jc@trillian.mit.edu>
# N: "Sith spirit"snd teeling"
# N: "Collected by J.O'Neill"
# Z:G
# (c/E)
# synth(samp)[ 100 ]:
#  ,n Chambers <jc@trillian.mit.edu>
# N: "Sith spirit"sn  paeling.
# N: "Collected by J.O'Neill"
# K:A
#  c>E)
# 6500 0.69997554481
# --- Model saved to: ./irish.ckpt-6500
# (100, 95) min: 5.99757e-13 max: 0.999965 mean: 0.0105263 std: 0.0818536
# original:[ 100 ]
#   G2 G2 c2 |
#         d2 f2 c2 f2 | BAGF ABGA | F2 D2 D2 CD | F2 D2 D2   :|
#
# X:1808
# T:The King Of The
# synth(amax)[ 100 ]:
#  |2 :2 |2 :|c        2 d2  2 e2 | B2GF  BcA | F2 D2 D2  D | F2 D2 D2   :|
# |X:1700
# T:The Filg of The H
# synth(samp)[ 100 ]:
#  z4fG   2 :|c       G2 d- d2  2 | B2GF  2GG   dd F2 D2 dA | F2=F2 D2  |:|
#
# X:1727
# T:Joe Pilc Of The H
# 6600 0.658541036248
# --- Model saved to: ./irish.ckpt-6600
# (100, 95) min: 4.10632e-13 max: 0.999979 mean: 0.0105263 std: 0.0830258
# original:[ 100 ]
#  B AGF|GBG FGA|BGE E2g|
# fdf ece|dcB AGF|(B/c/d)B AFd|AFD D2:|
#
# X:1011
# T:The Newmarried Couple
# N:"Coll
# synth(amax)[ 100 ]:
#   |2E G3d AGA|BGG E2 |
# add ece|dcB AGF|GB/c/d)B cFd|AFD D2:|
#
# X:8001
# T:The Bew arried Bougle
# N:"Colle
# synth(samp)[ 100 ]:
#  G\FB D2A AAA|
# GG E2:|
# aaf ece|deB AGF|GB/c/d)B cFd|DFD D2:|
# eX:8002
# T:Hhe Aew arriad Crlbte
# N:"Colle
# 6700 0.704789972901
# --- Model saved to: ./irish.ckpt-6700
# (100, 95) min: 3.02025e-12 max: 0.999872 mean: 0.0105263 std: 0.0800424
# original:[ 100 ]
#   (GECE)|GFED C2 (DE)|
# FEFG Afec|(dc)(AB) ceHdD|(DE)(FG) (AB)(GA)|F2 D2 D2||
#
# X:176
# T:The Humours of
# synth(amax)[ 100 ]:
#  |AA))) (2G  CD((DE)|FF2FG A2ec|ddcA(AB) ce~dB|(DE)(FG) (AB)(GA)|F2 D2 D2 |
# (X:151
# T:The Bumorrs of B
# synth(samp)[ 100 ]:
#  (Z2E)) (2GD CDD(DE)|FF=FG ABed|ddcdAAG) HA(d(|(DE)(EG) |ABc(GA)|F4 F2 D2:D
#
# X: 54
# T:The Momorrs of M
# 6800 0.66273635447
# --- Model saved to: ./irish.ckpt-6800
# (100, 95) min: 9.42097e-14 max: 0.999945 mean: 0.0105263 std: 0.0830795
# original:[ 100 ]
#   d2de | =fece d2d^f | g2dc BAGB | A2AA A2Bc |
#           defd gddB |  cBAc B2AG  | GBdg ecAF | G2GG G
# synth(amax)[ 100 ]:
#  |2 2|| ffefA d2(2f |
# g2dc B2GF | A4G2 Ac c |
# |        dd2dd  dBg | c 2AG BA G  | FFdg ecAF | G2GG G2
# synth(samp)[ 100 ]:
#  AB  || ffefe dc 2f |
# g2gc (AGF | AFd2 Acdc | |     D    2dd  dBg | ccecG B2 F || AFdg  gAF | G2GG G2
# 6900 0.679973723292
# --- Model saved to: ./irish.ckpt-6900
# (100, 95) min: 1.10105e-15 max: 0.999996 mean: 0.0105263 std: 0.0952799
# original:[ 100 ]
#  n America
# N:"Collected by J.O'Neill"
# B:O'Neill's 851
# Z:Transcribed by Dan G. Petersen, dangp@post6.t
# synth(amax)[ 100 ]:
#  stmurmganB:"Collected by F.O'Neill"
# B:O'Neill's 856
# Z:Transcribed by Dan G. Petersen, dangp@post6.te
# synth(samp)[ 100 ]:
#  sRiarmXanR:"Collected by F.O'Beill.
# B:O'Neill's 916
# Z:Transcribed by Dan G. Petersen, dangp@post6.te
# 7000 0.71332082808
# --- Model saved to: ./irish.ckpt-7000
# (100, 95) min: 1.50808e-11 max: 0.999364 mean: 0.0105263 std: 0.0760136
# original:[ 100 ]
#  (AEAB) (cded) | (cAB{d}c) A3 B | (cde^f) (^gaea) | c'ab>a a3 b |
# c'c'ba b-ee-d | c-gB-A G3 A-B | c-a
# synth(amax)[ 100 ]:
#  3B)B)|ccB)))|| B3B))c}c) (2 B | ((deff) (gga)a) | ('2b>a a> b |
# a'a'ba b>a >d | c>Ae-A G2 | B | c>Ba
# synth(samp)[ 100 ]:
#  BB)B)||cB)))|( B(A))d}c)ABG : | ccdcff)  =g3{a) | ('bb>b b'^| | a'a'ba c>fe>d | cBAe>~ G> | _ | c>da
# 7100 0.655802856982
# --- Model saved to: ./irish.ckpt-7100
# (100, 95) min: 5.71586e-14 max: 0.999848 mean: 0.0105263 std: 0.0840103
# original:[ 100 ]
#  gfe dcAc|B2 G2 G2 (dc)|
# BGBd gabg|abc'a gfed|(3(efg) (3(fga) (3(gab) (3(abc')|bgfg e^def|\
# gbdg egBd
# synth(amax)[ 100 ]:
#   e dcBG|dG G2 G2 (ec)|\BGBd Bdbg|abc'a gfed|e(eefg) (f(fga) (3(gab) (3(abc') bgfg eddef|
#
# gbdg egBd|
# synth(samp)[ 100 ]:
#  f/||2Bb|dGG(2 G2 (Ge)|
# dcAd Bbbg|a2c'a gbed|c(B^fe) ((ffga) (3(gag) (((aga') bgfg eddef"
#
# gedg ec d|
# 7200 0.659820394516
# --- Model saved to: ./irish.ckpt-7200
# (100, 95) min: 8.05091e-15 max: 0.999996 mean: 0.0105263 std: 0.0859828
# original:[ 100 ]
#  FG (A/B/c)A|BGG G2|]
#
# X:712
# T:OFF TO THE HUNT
# M:6/8
# L:1/8
# B:O'NEILL'S 712
# N:"collected by J. O'Neill
# synth(amax)[ 100 ]:
#    AABB/)). BGG G2:|
#
# X:882
# T:TuE OHRMHE HANT
# T:6/8
# L:1/8
# B:O'NEILL'S 700
# N:"collected by J. O'Neill"
# synth(samp)[ 100 ]:
#  DE|{BG/c). BGG G2:|
#
# X:196
# T:M'EIRHUEHE YUTGET:6/8
# L:1/8
# B:O'NEILL'S 111
# Z:"collected by J. O'Neill"
# 7300 0.685498251915
# --- Model saved to: ./irish.ckpt-7300
# (100, 95) min: 1.1012e-14 max: 1.0 mean: 0.0105263 std: 0.0829231
# original:[ 100 ]
#  ABc|!
# dded fdgd|fdaf gfed|fafd fafd|Bgec d2:|!
#
# X:333
# T:Ships Are Sailing
# Z: id:dc-reel-310
# M:C
# L:1/
# synth(amax)[ 100 ]:
#   c|d
# dedf cdfd|fdfd gfed|faad fafd|Bdec d2:|!
#
# X:22
#
# T:Stems Are Suiling
# Z: id:dc-reel-14
#
# M:C
# L:1/8
# synth(samp)[ 100 ]:
#  Gcdd
# MGe  cdcd|cgdf dfeg|faad eafd|Bdgg d2:|!
# fX:635
# T:Shep  aeerKhiling
# Z: id:dc-reel-280
# M:C
# L:1/8
# 7400 0.629914338887
# --- Model saved to: ./irish.ckpt-7400
# (100, 95) min: 3.07923e-16 max: 0.999998 mean: 0.0105263 std: 0.0905288
# original:[ 100 ]
#   cdef|g^fge dgfg||
#
# X:1509
# T:Merry Blacksmith, The
# R:reel
# N:"collected from F. O'Neill"
# B:"O'Neill's
# synth(amax)[ 100 ]:
#  |Ae  gefga dcfe|a
#
# X:1211
# T:Tarry Daacksmith
#  The
# R:heel
# N:"collected from M. O'Neill"
# B:"O'Neill's
# synth(samp)[ 100 ]:
#  D<e  gbfga dcdg|a
# eX:1395
# T:Byrry Blackmmith
#  Mhe
# T:seel
# N:"collected from F. O'Neill"
# B:"O'Neill's
# 7500 0.648085283041
# --- Model saved to: ./irish.ckpt-7500
# (100, 95) min: 4.45935e-13 max: 0.999984 mean: 0.0105263 std: 0.0818255
# original:[ 100 ]
#  )|eBc d2 c/B/|
# ABG (F/A/) z (d/e/)|(f>ga) (g/e/) z f|(g>ab) (b/a/)(g/f/)(e/d/)|eBTHc
# {Bc}d2||
#
# X:612
# synth(amax)[ 100 ]:
#   (2BAA2 c|B/|
# A2A GG/A/)(z (d/c/)|(f>ga) (g/e/) z f|(g>ab) (b/a/)(g/f/)(e/d/)|eBcHc (dA}d2 |
# (X:518
#
# synth(samp)[ 100 ]:
#
# 2cAAc c|B/|
# A2A GF/A/B ( Dd/c/)|(f>ef) (gef/) z (|(e>ab) (b/a/)(g/f/)(e/d/)|e2cHc (Bc}d2 .
#
# X:635
#
# 7600 0.645950607359
# --- Model saved to: ./irish.ckpt-7600
# (100, 95) min: 5.85211e-14 max: 0.99986 mean: 0.0105263 std: 0.0803842
# original:[ 100 ]
#  ffe|!
# dBB2 A2FA|d2d^c defg|affe f2ed|BABc def:|!
# g|aff2 afbf|afef afe2|afef a3e|fgfe dBAf|!
# aff2 afb
# synth(amax)[ 100 ]:
#  eddd
# dcB2 eFFA|ded2c defg|afd2 dBed|!AGc dBdg|!
#
# |fgf2 dfbf|afef dfef|ffgf a2e|fdae dBAF|!
# afd2 bfff
# synth(samp)[ 100 ]:
#  d|dd
# dDG| dFFA|dBd2c Befg|afd2 d2gf|cAGc dBfg|!
#
# eagff gfbf|afef dfee|afgc a2e|fdae dcAF|(
# afda bfb2
# 7700 0.610359545648
# --- Model saved to: ./irish.ckpt-7700
# (100, 95) min: 7.38784e-17 max: 1.0 mean: 0.0105263 std: 0.0948197
# original:[ 100 ]
#  lected by F. O'Neill
# B:O'Neill's 1371
# Z:Transcribed by Trish O'Neil
# M:C|
# L:1/8
# K:A
# A2(ed) cdec|A2(ec
# synth(amax)[ 100 ]:
#  l.ted by M. O'Neill
# Z:O'Neill's 1300
# Z:Transcribed by Trish O'Neil
# M:C|
# L:1/8
# K:A
# (2(3d) cdec|A2(ec)
# synth(samp)[ 100 ]:
#  e.ted by M. O'Neill
# Z:O'Neill's 1180
# Z:"ranscribed by Trish O'Neil
# M:C|
# L:1/8
# K:D
# A2Aed) cd(g|A2(ec)
# 7800 0.642514984608
# --- Model saved to: ./irish.ckpt-7800
# (100, 95) min: 1.55497e-12 max: 0.999902 mean: 0.0105263 std: 0.0860534
# original:[ 100 ]
#  | F4 (f>e) | d2 B2 {d}(cB) | G2 A>(G (3GFD) |
# ^F2 G2 (G>A) | B2 c2 (BG) | (A3/2B/4A/4 G2) G2 | G4 ||
# synth(amax)[ 100 ]:
#   d2 (G>e) |
# d4 B2 cd}(c>) | G2 (2GB G3BFE) | |F2 G2 GA>A) | B2 d2 (B>) | AA2 2B/4A/4 G2) G2 | G4 ||
#
# synth(samp)[ 100 ]:
#   C2 (G>e) | d4 B2 cd}(c>) | B3 (2FF G3dFD) |
# ED2 G2 dA>A) | B4 c2 (fG) | (A2 2B/4A/4 G2) G2 | E6 (|
#
# 7900 0.624175491333
# --- Model saved to: ./irish.ckpt-7900
# (100, 95) min: 3.2909e-15 max: 0.999999 mean: 0.0105263 std: 0.088051
# original:[ 100 ]
#
# T:Saddle the Pony
# Z: id:dc-jig-112
# M:6/8
# L:1/8
# K:G Major
# D|GBA G2B|def gdB|GBA G2B|AFD AFD|!
# GBA G2
# synth(amax)[ 100 ]:
#  B:Chidye Bhe Wond
# Z: id:dc-rig-163
# M:6/8
# L:1/8
# K:D Major
# B|GBd G2B|def gdB|GBA G2B|ABD AFD|!
# GBB G2B
# synth(samp)[ 100 ]:
#  |:Ahidye the Grny
# Z: id:dc-jig-265
# M:6/8
# L:1/8
# K:G Major
# g|GBA G2B|Aef gdB|G3A G3d|ABA A2D|!
# GBd G2B
# 8000 0.58048083514
# --- Model saved to: ./irish.ckpt-8000
# (100, 95) min: 6.16021e-14 max: 0.999709 mean: 0.0105263 std: 0.0818762
# original:[ 100 ]
#  AD (3FEDA2dB| ADFA BEEz| AD (3FEDA2Bd| (3efg fd ecdB|
# AD (3FEDA2dB| AD (3FED BEEz| DEFG AFAB| defd e
# synth(amax)[ 100 ]:
#    F3DED 2BB|AAD A BG z||AF (3FEDA2Bd| (3efg (d ecdB:|A2 (3FEDA2dB| AD (3FED AEEz| DEFG ABAB| defd ed
# synth(samp)[ 100 ]:
#  ||AdEED 2BB|
# AGDA BG z:
# AD D3FED 2dd||(eefe (d ecdf|:AD (3FED 2de| AD (3FED AdEc| DADG ABAB|Bdcfd ed
# 8100 0.629233634472
# --- Model saved to: ./irish.ckpt-8100
# (100, 95) min: 9.969e-13 max: 0.999964 mean: 0.0105263 std: 0.0798116
# original:[ 100 ]
#  AG ^FGAF | G4 G2 ||
# z2 | d3c db2a | gfdc d2z2 | f3d c2Bc | d=efd g2dc |
# B2A2 G3G | AGFD F2dc | B2AG
# synth(amax)[ 100 ]:
#    AFGA| | D2 z2 ||
#
# 2 | d3c dfaa | g2e2 A2e2 | c3d c3Ac | d4efd c2dc |
# B2A2 G3G | A2FD C2Dc | B2AG F
# synth(samp)[ 100 ]:
#  G|DF/AB |  2 z2z||
# |  | d3c d2aa | gfa  BgeB | F4g e2ac | deefd c2dc |
# B2AB G>E | A4AA c2z2 | B2(G ^
# 8200 0.618697282672
# --- Model saved to: ./irish.ckpt-8200
# (100, 95) min: 1.93801e-14 max: 0.999993 mean: 0.0105263 std: 0.0855527
# original:[ 100 ]
#   ((3AGA) ((3AGA) A>E | ((3AGA) ((3AGA) ((3AGA) A>E| (GABc) d3e|\
# d3e d2f2| d2e2 d4 | (cBAG) HE4 |]
#
#
# synth(amax)[ 100 ]:
#  |33eBA) AA3AGA) A>E |
# ((3AGA) ((3AGA) ((3AGA) A>E  (GAB)) d2e|
#
# dge d2 2|ed2e2 d2 ( ccBAG) AB4 |]
#
# X
# synth(samp)[ 100 ]:
#  ed3fGA) "A3AGA) (>E |
# (T3AGA) ((3AGA) ((3AGA) A>E  (GAGc) d2e|
#
# (ce d2 2|de2 f e2(( ecBAG) FE2 |]
#
# X
# 8300 0.592324492931
# --- Model saved to: ./irish.ckpt-8300
# (100, 95) min: 1.93292e-15 max: 0.999957 mean: 0.0105263 std: 0.0815789
# original:[ 100 ]
#  |G3 G2:|
# d/=e/|f2d d=e^f|g2d dcA|G2f f2g|afd d2=e|
# fga gf=e|f_ed cBA|GAB AG^F|G3 G2:|
#
# X:1055
# T:Bold
# synth(amax)[ 100 ]:
#   B G2||
#
# |-e/|f2d dceff|g2d dcA|G2A g2g|afd d2ef|
# fgf bfee|f2ed cAA|BAB cG^F|G3 G2:|
#
# X:1061
# T:Tlld
# synth(samp)[ 100 ]:
#  (2 G2||
# ||ee/|f2d deeff|g2d d=A|G2A ~2g|afd d^=f|
# f2f ffee|f2ed cBc|GAc cG^F|G2 G2:|
# BX:1640
# T:Brld
# 8400 0.624213676751
# --- Model saved to: ./irish.ckpt-8400
# (100, 95) min: 4.05535e-13 max: 0.999866 mean: 0.0105263 std: 0.0814442
# original:[ 100 ]
#
# A \
# | f2 f>e | d>B Bd | A>A FD | E4 \
# | FA AB | AF Dd | fd ec | d2- d ||
# || B \
# | A>d dd | B>d dd |
# synth(amax)[ 100 ]:
#  M2\
# | A> fee f d2-dAd | A>B FA | G> (
# | FA AB | AF EE | fd ec | d2  d ||
#
# | B \
# | (dB dd | B>d dd |
# synth(samp)[ 100 ]:
#  Ld|
# | (> dee | d2fbAd | A2B FA-| (  (
# | fA AB ||A2 EE | fd ec | d2  H |
#
# | B \
# | edd dd | e-d dd |
# 8500 0.585792991817
# --- Model saved to: ./irish.ckpt-8500
# (100, 95) min: 1.54834e-14 max: 0.999889 mean: 0.0105263 std: 0.0838937
# original:[ 100 ]
#  |e2 E2 E2 (ed)|cea^g a2 f2|
# gfga bagf|gfec dcBA|Bdce dfeg|f2 d2 d2:|
# |:(AG)|FAdA FAdA|B2 G2 G2 (GF)|
# synth(amax)[ 100 ]:
#   c e  GF (Af)|
# 2a^g a2 (2|
# g2ga gggf|gfec dcBA|Bcce dfeg|f2 d2 d2:|
# |:(3G)|FAdA FAdA|Bc (2 G2 (GF)|G
# synth(samp)[ 100 ]:
#   BAe  G2:GAf)|c2A^g a2 z2|
# gfga gagf|(fec dcBA|Gdce d2eg|f2 f2 e2:|
# |:(3G)|FAdA FAdf|Bc G2 E2 (GB)|G
# 8600 0.582472503781
# --- Model saved to: ./irish.ckpt-8600
# (100, 95) min: 1.38052e-14 max: 0.999999 mean: 0.0105263 std: 0.0882392
# original:[ 100 ]
#  du)
# Z:abc 1.6
# M:6/8
# R:Jig
# L:1/8
# K:D
# G | A3 cAG | A2d cAG | F2D DED | FAF GED |
# A3 cAG | A2G Ade |
# |
# synth(amax)[ 100 ]:
#   >
# Z:abc 1.6
# M:6/8
# R:Jig
# L:1/8
# K:D
# F | F2 cAG | A2d cAG | F2D DED | F2F GED |
# |B BAG | A2G Ade | f f
# synth(samp)[ 100 ]:
#  Mr
# Z:ab  1.6
# M:6/8
# R:Jig
# L:1/8
# K:G
# ( | F2 BdG | Add cAG | F2F DED F FFF GED |
# |B GAG | A2C Ade | | f
# 8700 0.616659794152
# --- Model saved to: ./irish.ckpt-8700
# (100, 95) min: 3.20391e-13 max: 0.999991 mean: 0.0105263 std: 0.0851027
# original:[ 100 ]
#  | (DFA) (DFA) | .G.A.B (TBAF) |
# | (DFA) (DFA) | .G.E.c | CDE | (TAGE) (TcBA) | (TGED) D2 ||
#
# X: 79
# T
# synth(amax)[ 100 ]:
#   (3EA) (DFA) | .G.E.B |cBAF) | | (BFA) (DFA) | .G.E.B | (DE | (TAGE) (TcBA) | (TGED) D2 ||
#
# X: 30
# T:
# synth(samp)[ 100 ]:
#   A3EA) (DFA) | (G.E.B |cBAF) |
# | (BFA) (DFA) | .G.E.B | (DE | (AA2E) (GcBA) | dTFED) D2 ||
# NX: 50
# T:
# 8800 0.568311036229
# --- Model saved to: ./irish.ckpt-8800
# (100, 95) min: 1.37288e-15 max: 0.999985 mean: 0.0105263 std: 0.086148
# original:[ 100 ]
#  ce | f2 (df) Bfdf | e2 (ce) Aece | dcBA GABc |
# e2 (ce) Aece | dcde fgaf | eagf edcB | AdcB A2 :||
#
# X
# synth(amax)[ 100 ]:
#  A | dd (df)  fdf | ed (ce) Aece | dcBA GABd |
# d2 (ce) Aece | dcde fgaf | gfgf edcB | A2dB A2 :||
#
# X:
# synth(samp)[ 100 ]:
#  '^F gd fdc) (fdf | ed Age) Aece | d2BA TABd |
# d- (ee) Aece | fcde fgaf   gfgf edcd | c2dA A2 :|
#
#
# X:
# 8900 0.572766633332
# --- Model saved to: ./irish.ckpt-8900
# (100, 95) min: 3.52573e-14 max: 0.999997 mean: 0.0105263 std: 0.0831008
# original:[ 100 ]
#   Bdg dBG | ceg gec | f3 e2f |
# gfe agf | gfe dcB | cBA GEG | ABA A2 :|
#
# X:747
# T:Nothing Can Sadden Us
# synth(amax)[ 100 ]:
#  |2  |BG | BBc ged | fe d2( |
# gfe fgf | gfe dcB | cBA eED | ABA A2 :|
#
# X:944
# T:Tothing Can Tadden Us
#
# synth(samp)[ 100 ]:
#  F | |BGB| Ddc Bfd | dB e2c |
# gfg f{f | gfe dcB | cAA ~EG | ABA A2 :|
# |X:734
# T:Aorhing Tar Sadde
#  Us
# 9000 0.60369431138
# --- Model saved to: ./irish.ckpt-9000
# (100, 95) min: 8.49983e-16 max: 0.999891 mean: 0.0105263 std: 0.0865257
# original:[ 100 ]
#  d (3dfa gf|dedc B2G2|!
# [1 d'2a2 b2g2|abag fdgf|(3ece (3gag (3fdf (3aba|g2gf g2:|!
# [2 G2GA GABc|d2 (3
# synth(amax)[ 100 ]:
#   b3dcd d>eeefB dAG2|A
# B1 dB2c2 b2g2|abag fddf|e3efe (3gag (3fdf (3aba|g2gf g2:|!
#
# 2 f2|F GABc|dee(3e
# synth(samp)[ 100 ]:
#  cc3d/d d>eeef: AAdA|A
# B1 d22c2 b2g2|abag fggd|e3efe (3gag d3fdf (3aba|g2gf g2:|!
#
# 1 G>BG GABc|dGe(3c
# 9100 0.551888729036
# --- Model saved to: ./irish.ckpt-9100
# (100, 95) min: 8.38766e-16 max: 0.999996 mean: 0.0105263 std: 0.0834116
# original:[ 100 ]
#  efg adfd|gece (fd) d2|
# defg adfd|cdef gedc|defga2 (gf)|gbag (fd) d2||
#
# X:1549
# T:Mountain Rose, The
# R
# synth(amax)[ 100 ]:
#  dg a2a||cede ggd) d2|
# (gfg abfd|cdef gedB|defg 22(gf)|ebag (fd) d2||
#
# X:1223
# T:Monntain Bose, The
# R:
# synth(samp)[ 100 ]:
#
# a a3a/ cfeegcfd)dd2|
# (Afg a2fd|(def gedB|d2fg 2 (gf)|dbag (fd) d2|
#
#
# X:1177
# T:Toontaln Tose
#  The
# R:
# 9200 0.581629442573
# --- Model saved to: ./irish.ckpt-9200
# (100, 95) min: 7.39913e-13 max: 0.999952 mean: 0.0105263 std: 0.0855349
# original:[ 100 ]
#  2(AB) |
# | c2c2 (dc)(BA) | e2c2 a2gf | ecBA GBcd | c2A2 A2 ||
# || (AB) \
# | c2d2 c2a2 | e2c2 (dc)(BA) |
# synth(amax)[ 100 ]:
#   cB) ( | (2c2 (dc)(BA) | G2c2 A2gf | e2BA F3dd | e2A2 A2 ||
#
# | (cG) \
# | c2c2 (2a2 | B2c2 ddc)(BA) |
# synth(samp)[ 100 ]:
#  LdF) | ( (2cd (dc)(BA) | G2(2 A2af | e2BA dAHd | E2c2 A2 (|
#
# | (BG))\
# | c2c2 f2(2 | c^c2 ddc)(eA) |
# 9300 0.57944298923
# --- Model saved to: ./irish.ckpt-9300
# (100, 95) min: 1.15167e-15 max: 0.999985 mean: 0.0105263 std: 0.0825794
# original:[ 100 ]
#  DE FDdB|cAGE FDEC|!
# A,DDE F3G|A2Gc Adde|fdd2 dcAd|cAGE FDD2:|!
# d3A c3A|d3A cAGA|d3A c3A|GEcE EDD2|!
#
# synth(amax)[ 100 ]:
#  EFF2D||cABE FDEC|!
# D,DDE F2G|AcGc Addc|fdd2 dcAd|cAGE FDD2:|!
# d2e c3A|d3A cAGA|d3d B3d|dEEE EDD2:!
# d
# synth(samp)[ 100 ]:
#  FFF2E||ABBE cE:C|!
# A,DDE FDG|AGGc Adde|fdde gcAB|cAGA EDC::|!
# ABe c3e|G3A BAGc|c3d F3B|GEDE DDDC:!
# d
# 9400 0.539772455096
# --- Model saved to: ./irish.ckpt-9400
# (100, 95) min: 3.5519e-14 max: 0.999997 mean: 0.0105263 std: 0.0854963
# original:[ 100 ]
#  k, rjs@gsp.org"
# K:G
# B | A2 (Ag) fde^c |  A2 (Ac) BGGB | A2 (Ag) fdef | {a}gfgd  BG G :|
# f | eaaf
# synth(amax)[ 100 ]:
#  . rjs@gsp.org"
# K:A
#   | (2 (AG) fde^c | AA2 (Ac) BGGB | A^ (AG) fde^ | ga}gfge  Bc G :|
#
#  | eaag
# synth(samp)[ 100 ]:
#
#  rjs@gsp.org"
# K:A
# B>| d2 (AG) fdegf | dd2 (Ac) BGGB | AE aAB) fde^ | ca}gfge  BG G :|
# f2| egaf
# 9500 0.577510776818
# --- Model saved to: ./irish.ckpt-9500
# (100, 95) min: 1.38824e-14 max: 0.999911 mean: 0.0105263 std: 0.0822733
# original:[ 100 ]
#  dcd ecA | ABc deg | fge d2 ||
# d \
# | (dg).b .b(ag) | (df).a .a(fd) | (dg).b .b(ag) | (d2 f) (afd) |
# (
# synth(amax)[ 100 ]:
#     e2A | ABc d2f | f3f d2 ||
# | |
# | df>).g .b(ag) | (d2).a (a(fd) | (dg).b .b(ag) | (d2 =) (efd) | (g
# synth(samp)[ 100 ]:
#  )  [gAF| A>c d2f \ f3f d2 ||
# | |
# | dd/).g .a(ag) | (d2).a (a(fd) | ddg).  .g(ag) | adg =) (ffd) | (d
# 9600 0.562637211084
# --- Model saved to: ./irish.ckpt-9600
# (100, 95) min: 3.97492e-15 max: 0.999964 mean: 0.0105263 std: 0.0784459
# original:[ 100 ]
#  2GA|!
# BcdB cdec|d2cB cBAG|F2EF D2 (3DEF|GAGF Eccc|dedB cBAF|!
# GGDD EEFF|GGEE FFGG|AAFF GGAA|BBGG AAB
# synth(amax)[ 100 ]:
#   2 !
# AdBf GBef|d2GB c3AG|F2E2 DCG(3AEF|GAGF EAcc|d^dB cBAF|!
# G2BG BGFA|GFED FGGA|A2FA GGAB|BGdG AGAG
# synth(samp)[ 100 ]:
#  )2 B
# dGBe ABef|d2dB ABAG|A2E2 DGFz3AEF|!AB^ Ecet|d^dB ddAF|!
# G2BC CGFG|GFED FGGG|A2GE GAGB|B2GG AGAB
# 9700 0.525238393843
# --- Model saved to: ./irish.ckpt-9700
# (100, 95) min: 3.16693e-18 max: 1.0 mean: 0.0105263 std: 0.090409
# original:[ 100 ]
#  he Clock in the Steeple
# M:C|
# L:1/8
# R:Reel
# B:O'Neill's 1248
# N:
# Z:Transcribed by Trish O'Neil
# K:A
# g|a2
# synth(amax)[ 100 ]:
#  e Booak
# Rn the Girlple
# M:C|
# L:1/8
# R:Reel
# B:O'Neill's 1211
# N:CZ:Transcribed by Trish O'Neil
# M:G
# E|ae(
# synth(samp)[ 100 ]:
#  i
# Cooak
# Rn the Lteep
# e
# M:C
#
# L:1/8
# R:Reel
# B:O'Neill's 1256
# N:CZ:Transcribed by Trish O'Neil
# M:A
# (|a2
# 9800 0.556293726265
# --- Model saved to: ./irish.ckpt-9800
# (100, 95) min: 6.0771e-16 max: 0.999998 mean: 0.0105263 std: 0.090715
# original:[ 100 ]
#  Z:Transcribed by Chris Falt, cfalt@trytel.com
# K:Am
# (e/2>d/2)|BAA ABG|Ad2 e/2^f/2g2|a>ge/2d/2 B2A|G3-
# synth(amax)[ 100 ]:
#  : ranscribed by Jhris Falt, cfalt@trytel.com
# K:G
#
# (e/2fd/2)|BAA ABc|A>f e/2^f/2g2|a/ge/2d/2 BA GG3/G
# synth(samp)[ 100 ]:
#  :Transcribed by Dhris Falt, cfalt@trytel.com
# K:E
#
# Eg/2ff/2) dAAdABd|Ad^ fd2^f/2g2|a>g /2d/2 A  2G3/G
# 9900 0.545765261948
# --- Model saved to: ./irish.ckpt-9900
# (100, 95) min: 5.9445e-17 max: 0.999996 mean: 0.0105263 std: 0.0885437
# original:[ 100 ]
#   Major
# Bc|(3dcB ge dBed|BGDG ABAG|FGAB cBcg|(3agf (3gfe dcBc|!
# (3dcB ge dBed|BGDG ABAG|FGAB cdef|(3g
# ...
# original:[ 100 ]
#
# ^cFF2 Bcdc|BGBd e2ed|cdeg fde^c|dfe^c d2:|!
# ag|fdfg a2gf|ecef g3a|fggf gfe^c|dfed ^cded|!
# ^cFF2 Bcd
# synth(amax)[ 100 ]:
#  ZGdF  Bcdc BABd ef d|cdeg fde^c|dfe^c d2:|!
# ag|fdfg a2gf|ecef g3a|fggf gfe^c|dfed ^cded|!
# ^cFF2 Bcdc
# synth(samp)[ 100 ]:
#  MGAA  dcdc (ABd ed d|cBAg fde^c|dfe^c d2:|!
# ^g|f2c^ afgf|ecef g3a|fgaf gfe^c|dfed ^cded|!
# ^cFF2 Gcdc
# 15100 0.403633708656
# --- Model saved to: ./irish.ckpt-15100
# (100, 95) min: 1.31727e-22 max: 1.0 mean: 0.0105263 std: 0.0913335
# original:[ 100 ]
#  ||
#
# X:1234
# T:Over the Bridge to Peggy
# M:C|
# L:1/8
# R:Reel
# B:O'Neill's 1234
# N:Collected by Ennis
# Z:Tran
# synth(amax)[ 100 ]:
#
#
#
# X:110
#
# T:Tner the Bridge to Peggy.R:C|
# L:1/8
# R:Reel
# B:O'Neill's 1236
# N:Collected by Fnnis
# Z:Trans
# synth(samp)[ 100 ]:
#    dX:5473
# T:Tner the Mredgetto Metry.N:C|
# L:1/8
# N:Reel
# B:O'Neill's 1144
# N:Collected by Cnnis.Z:Trani
# 15200 0.416946051419
# --- Model saved to: ./irish.ckpt-15200
# (100, 95) min: 4.82302e-19 max: 1.0 mean: 0.0105263 std: 0.0928203
# original:[ 100 ]
#  cond section is 1/4 (should be dotted.)
# N:The accidental on the last note of the first section shoul
# synth(amax)[ 100 ]:
#   ln wection is 1/8 (should be dotted.)
# N:"he accidental on the oast note of the first section hhould
# synth(samp)[ 100 ]:
#  |ld wecoion is 1/8 (should be dotted.)
# N:"he sctide t teof the 1ast note of the first shction
# htould
# 15300 0.403083429635
# --- Model saved to: ./irish.ckpt-15300
# (100, 95) min: 7.80581e-18 max: 0.999999 mean: 0.0105263 std: 0.0892268
# original:[ 100 ]
#  (3ABA (3GFE|!
# D2FA dAFD|CDEF G2FG|AdcB AGFE|D2CE D2:|!
# de|fefg fedc|BABc B2cd|edef edcB|(3ABA ^GB A2
# synth(amax)[ 100 ]:
#  3ABc)F3GFE
#
# D2FA dAFD|CDEF G2FE|AdcB AGFE|D2FE D2:|!
# de|fefg fedc|BABc BAdd|edef edcB|(3ABA ^GB A2
# synth(samp)[ 100 ]:
#  3FBc)F3GAG
#
# D2FA d2FA|CDEF G2FE|AdcA ABFE|D2(E D2:|!
# fe|fefg fadB|dABc BcdB|edef edcB|A3ABA EGB A2
# 15400 0.364405503273
# --- Model saved to: ./irish.ckpt-15400
# (100, 95) min: 1.53895e-22 max: 1.0 mean: 0.0105263 std: 0.0921192
# original:[ 100 ]
#  ailbox.swipnet.se
# M:6/8
# L:1/8
# K:G
# D|DGG BAG|AFD FDC|DGG BAG|Add cAG|
# DGG BAG|AFD F2G|FED F2G|Add cAG
# synth(amax)[ 100 ]:
#  nrbox.swipnet.se
# M:6/8
# L:1/8
# K:A
# G|GGG BAB|AFD FDC|DGG BAG|Add cAG|
# DGG BAG|AFD F2G|FED F2G|Add cAG:
# synth(samp)[ 100 ]:
#  nmbox.swipnet.se
# M:6/8
# L:1/8
# B:A
# G|G2G BAB|AFD FDC|DGG BGG|
# dd cAG|
# DGG GGG|AGD DDG|FDD F2G|Add cAG|
# 15500 0.409643301666
# --- Model saved to: ./irish.ckpt-15500
# (100, 95) min: 1.45661e-18 max: 1.0 mean: 0.0105263 std: 0.0830245
# original:[ 100 ]
#  fg | G>AG GED/D/ |
# | cec BdB | A>GA BGE/E/ | GFE (D<d)c | B>cA G2 ||
#
# X: 249
# T: The Bride of Malahid
# synth(amax)[ 100 ]:
#    e (2BG G2D C/ |
# | G2c BdB | AGBA BGE E/ | GFE DD2d)c | B>cA G2 ||
#
# X: 241
# T: The Blide of Malanine
# synth(samp)[ 100 ]:
#  g|d (6gG GED 2/ |
# | AAc BcB | AGGA BGE E/ | GFA DD>B)g | B>(A G2:|]
#
# X: 260
# T: Khe Boige of Malawide
# 15600 0.41942543149
# --- Model saved to: ./irish.ckpt-15600
# (100, 95) min: 2.28027e-20 max: 1.0 mean: 0.0105263 std: 0.0903534
# original:[ 100 ]
#  ga gfed | cdef gfed | eaab c'bag | e2 a2 a2 (ef) |
# ((3gfe) af ((3gfe) dB|cdeg g2 (fg)|((3agf) ge fde
# synth(amax)[ 100 ]:
#  fggfdd|| Bdef gfed | c2af c'bag | e2 a- a2 (ef) |
#  (3gfe) df ((3gfe) dB|c2eg g2 (fg)|((3agf) ge fdec
# synth(samp)[ 100 ]:
#  e)Gfd || gAef gfgd | efag c'bag | e2 d2 f2 (ef) |
# g(3afe) af ((3efe) dB|ceeg g2 (fg)|((3agf) ge fdec
# 15700 0.413622865975
# --- Model saved to: ./irish.ckpt-15700
# (100, 95) min: 3.08467e-18 max: 1.0 mean: 0.0105263 std: 0.089291
# original:[ 100 ]
#   Ade fed |
# cAF G2 G | ABc AdB | cAF GFG | Adc d2 ||
# || g | fed efg | ecc gcc | fed efg | age d2 (d/e
# synth(amax)[ 100 ]:
#  |2d||2d | |AF GA G | ABc AdB | cAF GFG | Ade d2 ||
# || ( | fed efg | ecc gcc | fed edg | age d2 (d/e/
# synth(samp)[ 100 ]:
#  Oi e|/dB| gAF GBBG | {=c BdB | cAF GFG | Adc d2 |]
#
# | G | fed edg | ecc gcc | fBd edg | fgf d> (d/e/
# 15800 0.422816573381
# --- Model saved to: ./irish.ckpt-15800
# (100, 95) min: 7.82e-18 max: 1.0 mean: 0.0105263 std: 0.0929468
# original:[ 100 ]
#   | A6- | A4 (AB) |
# c2 e2 c2 | B2 g2 B2 | A2 G4- | G4 (e>d) |\
# (c2 B2 A2) | (E2 ^F2 ^G2) | A6- | A4 |
# synth(amax)[ 100 ]:
#  | (2  | A2 |AB) |
# c2 (2 c2 | B2 g2 B2 | A2 G4- | G4 (e>d) |\
# (c2 B2 A2) | (E2 AF2 ^G2) | A6- | A4 ||
# synth(samp)[ 100 ]:
#    ( - | A4-|AB) \
# c2 e2 c2 | B2 G2 e2 | A2 (4 4| G4 (eef) |\
# (c2 Bc A2) | (E2 AF2)^G2) | A2- | A4 |]
# 15900 0.395044930875
# --- Model saved to: ./irish.ckpt-15900
# (100, 95) min: 1.71574e-20 max: 0.999999 mean: 0.0105263 std: 0.088605
# original:[ 100 ]
#  Bce dcBA | Ggfg edcB | {d}c2A2 A2B-c |
# | dBBd ecce | fdef {a}g2~f-e | dgfe dcBA | B2G2G4 :|
#
# X:1649
#
# synth(amax)[ 100 ]:
#  A  |BBA | G2fa edBB | cd}c2A2 A2B-c |
# | dBAd ecce | fdef ga}g2 f-e | dgfe dcBA | B2G2G2 :|
#
# X:1685
# T
# synth(samp)[ 100 ]:
#  A fdBAA | B2ga edBB | cd}c2 > A2Bcc |
# | dBA> ecce | fdff {a}g2ef-e | dgfe dcBA | B2G2G2 :|
#
# X:1604
# T
# 16000 0.390663236082
# --- Model saved to: ./irish.ckpt-16000
# (100, 95) min: 1.3344e-18 max: 0.999998 mean: 0.0105263 std: 0.0892955
# original:[ 100 ]
#  e|d2 b afd|afd fga|\
# [1 bge afd ecA cde:|[2 Bge cAc|ded d2||
# ||(B/c/)|d2 d' d'ag|fdd def|gag bge|cAA
# synth(amax)[ 100 ]:
#   dc Bda2d|efd fga|b
# b1 bge afd ecA cde:|[2 Bge cAc|ded d2||
# ||(B/c/)|d2 d' d'ag|fdd def|gag bge|cAA
# synth(samp)[ 100 ]:
#  dd> c a2dfffd fga b
# b1 bge afd ecd cde:|[2 Bge cAc ded d2||
# ||BB/c/)|d2 d' d'ag|fd  def|gaf fge|cAA
# 16100 0.411488099396
# --- Model saved to: ./irish.ckpt-16100
# InternalErrorTraceback (most recent call last)
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#
# /usr/lib/python3.4/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/framework/errors.py in raise_exception_on_not_ok_status()
#     462           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 463           pywrap_tensorflow.TF_GetCode(status))
#     464   finally:
#
# InternalError: Blas SGEMM launch failed : a.shape=(64, 512), b.shape=(512, 1024), m=64, n=1024, k=512
# 	 [[Node: rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/concat, rnn/RNN/MultiRNNCell/Cell0/BasicLSTMCell/Linear/Matrix/read)]]
# 	 [[Node: loss/Mean/_23 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_65031_loss/Mean", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InternalErrorTraceback (most recent call last)
# <ipython-input-17-e103fd8accb1> in <module>()
#       8              max_iter=50001,
#       9              model_type=model_type,
# ---> 10              ckpt_name=ckpt_name)
#
# <ipython-input-12-e2d983d407ad> in train(txt, batch_size, sequence_length, n_cells, n_layers, learning_rate, max_iter, gradient_clip, ckpt_name, keep_prob, model_type)
#      59                         model['Y']: Ys,
#      60                         model['keep_prob']: keep_prob}
# ---> 61             out = sess.run([model['cost'], model['updates']], feed_dict=feed_dict)
#      62             avg_cost += out[0]
#      63
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     983         except KeyError:
#     984           pass
# --> 985       raise type(e)(node_def, op, message)
#     986
#     987   def _extend_graph(self):
#
# InternalError: Blas SGEMM launch failed : a.shape=(64, 512), b.shape=(512, 1024), m=64, n=1024, k=512
# 	 [[Node: rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/concat, rnn/RNN/MultiRNNCell/Cell0/BasicLSTMCell/Linear/Matrix/read)]]
# 	 [[Node: loss/Mean/_23 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_65031_loss/Mean", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# Caused by op 'rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/MatMul', defined at:
#   File "/usr/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/traitlets/config/application.py", line 596, in launch_instance
#     app.start()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/kernelapp.py", line 442, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tornado/ioloop.py", line 883, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/kernelbase.py", line 391, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/ipykernel/ipkernel.py", line 199, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2723, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2825, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2885, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-e103fd8accb1>", line 10, in <module>
#     ckpt_name=ckpt_name)
#   File "<ipython-input-12-e2d983d407ad>", line 31, in train
#     model_type=model_type)
#   File "<ipython-input-11-b170f2dcabc7>", line 72, in build_model
#     initial_state=initial_state)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn.py", line 218, in rnn
#     (output, state) = call_cell()
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn.py", line 205, in <lambda>
#     call_cell = lambda: cell(input_, state)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn_cell.py", line 682, in __call__
#     output, new_state = self._cell(inputs, state, scope)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn_cell.py", line 813, in __call__
#     cur_inp, new_state = cell(cur_inp, cur_state)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn_cell.py", line 310, in __call__
#     concat = _linear([inputs, h], 4 * self._num_units, True)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/rnn_cell.py", line 907, in _linear
#     res = math_ops.matmul(array_ops.concat(1, args), matrix)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/math_ops.py", line 1398, in matmul
#     name=name)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/ops/gen_math_ops.py", line 1348, in _mat_mul
#     transpose_b=transpose_b, name=name)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/framework/op_def_library.py", line 749, in apply_op
#     op_def=op_def)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/usr/local/python3-tensorflow-gpu/lib/python3.4/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# InternalError (see above for traceback): Blas SGEMM launch failed : a.shape=(64, 512), b.shape=(512, 1024), m=64, n=1024, k=512
# 	 [[Node: rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/RNN/MultiRNNCell_78/Cell0/BasicLSTMCell/Linear/concat, rnn/RNN/MultiRNNCell/Cell0/BasicLSTMCell/Linear/Matrix/read)]]
# 	 [[Node: loss/Mean/_23 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_65031_loss/Mean", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]

# %%
# TF version
print(tf.__version__)
# Out:
# 0.11.0rc0

# %%
## 4 - Sample from the trained model

ckpt_name = 'irish.ckpt-16000'  # Trained model for sampling

output = infer(irish_txt,
              ckpt_name,
               5000,  # num of iterations to run for; num of characters to generate
              n_cells=n_cells,
              n_layers=n_layers,
              gradient_clip=5.0,
              learning_rate=learning_rate,
              sampling='prob')
# Out:
# ### About to infer...
# ### Model restored:  irish.ckpt-16000
# :1/82
# T:O'Ee THug
# M:6/8
# L:1/8
# B:O'Neill's 1444
# N:"collected by Gillan"
# Z:Transcribed by A. LEE WORMAN
# K:G
# D2|G2GA G2 (BA)|G2 (BG) A2 (GE) | GcAc    BGAF   | T(ED) (DE) G2 (cd) | ((3efg) (fa)         b ((3{e}^def) (=F3 F) (A>>G) | F4 (D>E) \
# | FA D2 ((3ABc) | d2 ((f/{a}ge) afed | ((3cBA) (eA) fagb | afec        defd | ((3cBA) (eA) fAeA  | fB ((3cBA) Bcde|
#          fefg afge | fafd  B2 ef | T(gf)(eg) f(a {f}gf)af | ((3gab) (af) gfed               |
# | e2 (ea) gedB      | (TAc) e2    | (cd) e2 (dc) |    BABF   A2 ((3DEF) |
#    Gceg  (fd)fd | ((3cdc) ((3BcB) {B}A2 GA | ((3BAG) AG ((3BAG) A2 |\
# defg a2 (ab/a/) | (aba) g2    | Tbgb  efge    |
#             eg{a}gf (((3gfe) dc | ((3Bcd) Ac  (B/A/G/E/ D/2E/2G/2A/2 B2) | c4 cc | (~dA) (TBA) "End"egfg       eage  | dBAB G2        z2  ||
# ef g2 (a/g/a)      | T agaf      gefd |  ((3efg) (fa)          agfe         | f2 (fg)      agfe  |   faaf                 agef |    defe            fbba | gfed     (cB) A2 ||
# ((3aba) (3(fga) g2 ag | ((3efg) (dg) ((3aga)  be Tea   | ((3aba) (eg)    abag       | afec T(BA) A2 ||
# (e^f) (ga) (gf)(ed) | faaf g2 (ef)| gfed     (((3fga)  ee  | fedB           cBAG       |
# A2 ((3efg)     (((3fgf)(ef) {e}d2 efge|| agab aeca |
#       ((3gab) af   ecAc | ((3(efg) ((3bag) a2 ((3efg) | agae faec |   d2 (af) gfed | eAAB          (cd)           | ecBc       TBG E2 :|
# A2 cB A((3GAG) FE | (AB)AF    G2 (AB) | cBAB  cdef  |   gfge   BgdB |  G2 ((3Bcd)   edBd      | eaaa f2 (ea) |
#      e2 (ae) feAA  |       GBAc    BE (3ABc |   defd                 Bcde    | fdfa               fdec        | (T(fa)af  e2     |]
#
# X:1834
# T:The Lawshin's Agid
# B:O'Neill'ss Marsfureave
# R:reel
# N:"collected from Fielding"
# B:"O'Neill's Dance Music of Ireland, 1514"
# T: an traisio.tura.ca.
# Z:transcribed by John B. Walsh, walsh@math.ubc.ca 8/23/96
# M:C|
# L:1/8
# K:D
# ((3DEF)|GABG EFGE|ABcA FGAF|GBdg ecAG|F2E2 D2:|
# |: (fg)|e>g ((3{a}gfg) b>(g (3agb) a>f | (3(gag) (3(agf) ((3gfe) ((3fed) | d8 ((3efg) ed  | e2 (ag) afdf |    gbag      faef       | ((3fga) ec    T(fe) Tee    :|
#            (Td(e/2f/2g/2a/2g) (f/2a/2g/2f/2) | e(fg) afdf |    gfge 2 ((3fgf) ((3agf) (ec) | dbag      faea     | c'ab( af)       | efge  (fd) d2 |
#     ((3ABc) dc  (Tdcd) ((3fga)    | ^f(gfe) d2 f | (eg)(f e)(d B)(A/2G/2) | FAAg       faec | {a}(cA)AA  (cd)       | cdec  dcAc | ((3Bcd) Ac BE (3EBc |
#          fcdc Aceg | aecA dcBA | (Tfeg) (fd) d2 |
# |1 (fgf)  fgec | ((3fga) ef       dcBA  | (TBA)Bc (Tgfed) | ((3cBA) (eA) f2 (ea) | e^def gfef | edgB A2 (AE) |
#        (FG) AG ((3BAG) A2 ((3Bcd) | e(f{e}d2 cA) Bcde | f2 (fd) gfec |   dcBA  TGFED    |
# (TBA D)(DE)   FAFA  | D(D)(FE)  D2 (EG) | FGEF D2 (dc) | BdBG (3(ABc) AF | G2 GG G2 :|
# |: (d>e) | f2 ed e2 f2 | a2 g2 f2 ef         g2 ef g2   ag    fgaf      gfed           BcdB | cAAB         ((3cBA) | BAG A2 G |
#      EDE G2 A BGE | D2 D EDB, A,D  | A,>B, A,2 A, |
# Bdc A2G G2d | (ded) (dcA) | B2 A G2 D G-e |]
#
# X:1130
# T:Erlles'
# N:.se fissing fiss, (9) (of)g2|
# (3fga fd ecA"((3A/B/c/=e}d)cd (3(efg) (3(ded) (3(cdc)|\
# | B>(A (3{A}(.E.F) {A}(GF)EF | D(3Bcd F>AD>FA>d | (3efe f>d e>cA>G |
# (3(A,B,) A,2 D/E/F/A/ BAcB|A>DDE FDGF|(C>DF) G2A|(BdcA) (FGA)|Sd2(Ad) faaf|edcB A2 (fa)|T(gf)(ed) (fd) (de) cAcE|((3ddd) (fd) ecAG|EFGA T(BA) A2||
# A2|(A(fed) ecAG|(D<(FD) (E<A) DC|(DF)(FA) (Gd)de|((3fed) ef ((3efe) ce|
# fdad fdfd|  ((3(faf) df a2 (Af) | gfec     defg   | aged           e2 (fg) | ((3agf) ec         (fd) :|2 (d<(e {g}fagf) eaaf | gece dcBA |
#           fcAag afed | cAec    cBAB  | ^c2  dA  A2     ||
#    B    | eceg       agfe | fafd      ecAg   | fef    geeg    | fedf   ec  cd   |
#          Bcde  fgef | gfge   fedc | B2 G2 G2 (cd) | efed cA A2 ||
# a2 ((3edc) ((3BcB) | (EA)AB (cB) A2 |   BcAc       Beef     e2 g2         |  efge   edeg |  ((3gfe) ((3fed) ((3cBA) | ((3cBA) ((3BA^G) (A3 G) (G>A) | B>A ((3BAE) A2 ((3AGE) | GABG A2 G2    :|
# e3 (dB) (AB) | TG2 A2 B2 B2   | ~B2 (gf) e2 (ag)  | f2 (fa) gfe^d | ((3efe) ((3gee) d(BAB) | (GE) (DE)    (GF) G   | (AG) FE FE    | DEFD    ECCE                                   | (Ac)ee  faea       | baff e- d2     |]
#
# X:1450"TTiish Aoner
# M:C
# L:1/8
# N:"collected by Cronin"
# B:O'Neill's 1560
# M:C|
# K:D
# ((3ABc)|dAFA GBAG|FADF GBAG|FAdf {a}g2 (bg)|(af)(ge) fdfd|((3ABc) GA ((3Bcd) AF | D(~EF)(ED) D2       :|
# |: (Bd) | f(a{b}a)f  gfed  |  ((3Bcd) AG  FGAc | B2 {B}AG     E2  (GE) |
# D2 ((GA) B-c dB | cA Bc d2 ge | dB  BA A2 |]
#
# X:1494
# T:Crosing the Vad
# M:C|
# L:1/8
# N:"collected by J. O'Neill"
# B:O'Neill's 1775
# R:Hornpipe
# N:"2nd Setting."
# B:O'Neill's 1713
# R:Hornpipe
# Z:"Transcribed by Bob Safranek, rjs@gsp.org"
# K:G
#    d | e3 d ((3efe) ce | d2 d2 d2 (cB) | c2 (dg) ed (c/B/)(A/G/) | B2 gB     efge    |  d2 B(G G)EG/2-A/2 |
# B dg Gg BG | eA BA FA | BGGA      GABc | dcdf ecAG        |\
#    BGBd  cBAG  |  Beed            cBce   | dfba bagf | edef                              efge| dBGB A2     |]
#
# X:1454
# T:Feash The Stilly's Hornpipe
# M:6/8
# L:1/8
# B:O'Neills 1661
# N:"collected by Gillan"
# Z:transcribed by John B. Walsh, walsh@math.ubc.ca 8/23/96
# M:C|
# L:1/8
# K:D
# FDAD dD BD|ABcA BG G2 Hx:|
# ((5001,)
# 	:1/82
# T:O'Ee THug
# M:6/8
# L:1/8
# B:O'Neill's 1444
# N:"collected by Gillan"
# Z:Transcribed by A. LEE WORMAN
# K:G
# D2|G2GA G2 (BA)|G2 (BG) A2 (GE) | GcAc    BGAF   | T(ED) (DE) G2 (cd) | ((3efg) (fa)         b ((3{e}^def) (=F3 F) (A>>G) | F4 (D>E) \
# | FA D2 ((3ABc) | d2 ((f/{a}ge) afed | ((3cBA) (eA) fagb | afec        defd | ((3cBA) (eA) fAeA  | fB ((3cBA) Bcde|
#          fefg afge | fafd  B2 ef | T(gf)(eg) f(a {f}gf)af | ((3gab) (af) gfed               |
# | e2 (ea) gedB      | (TAc) e2    | (cd) e2 (dc) |    BABF   A2 ((3DEF) |
#    Gceg  (fd)fd | ((3cdc) ((3BcB) {B}A2 GA | ((3BAG) AG ((3BAG) A2 |\
# defg a2 (ab/a/) | (aba) g2    | Tbgb  efge    |
#             eg{a}gf (((3gfe) dc | ((3Bcd) Ac  (B/A/G/E/ D/2E/2G/2A/2 B2) | c4 cc | (~dA) (TBA) "End"egfg       eage  | dBAB G2        z2  ||
# ef g2 (a/g/a)      | T agaf      gefd |  ((3efg) (fa)          agfe         | f2 (fg)      agfe  |   faaf                 agef |    defe            fbba | gfed     (cB) A2 ||
# ((3aba) (3(fga) g2 ag | ((3efg) (dg) ((3aga)  be Tea   | ((3aba) (eg)    abag       | afec T(BA) A2 ||
# (e^f) (ga) (gf)(ed) | faaf g2 (ef)| gfed     (((3fga)  ee  | fedB           cBAG       |
# A2 ((3efg)     (((3fgf)(ef) {e}d2 efge|| agab aeca |
#       ((3gab) af   ecAc | ((3(efg) ((3bag) a2 ((3efg) | agae faec |   d2 (af) gfed | eAAB          (cd)           | ecBc       TBG E2 :|
# A2 cB A((3GAG) FE | (AB)AF    G2 (AB) | cBAB  cdef  |   gfge   BgdB |  G2 ((3Bcd)   edBd      | eaaa f2 (ea) |
#      e2 (ae) feAA  |       GBAc    BE (3ABc |   defd                 Bcde    | fdfa               fdec        | (T(fa)af  e2     |]
#
# X:1834
# T:The Lawshin's Agid
# B:O'Neill'ss Marsfureave
# R:reel
# N:"collected from Fielding"
# B:"O'Neill's Dance Music of Ireland, 1514"
# T: an traisio.tura.ca.
# Z:transcribed by John B. Walsh, walsh@math.ubc.ca 8/23/96
# M:C|
# L:1/8
# K:D
# ((3DEF)|GABG EFGE|ABcA FGAF|GBdg ecAG|F2E2 D2:|
# |: (fg)|e>g ((3{a}gfg) b>(g (3agb) a>f | (3(gag) (3(agf) ((3gfe) ((3fed) | d8 ((3efg) ed  | e2 (ag) afdf |    gbag      faef       | ((3fga) ec    T(fe) Tee    :|
#            (Td(e/2f/2g/2a/2g) (f/2a/2g/2f/2) | e(fg) afdf |    gfge 2 ((3fgf) ((3agf) (ec) | dbag      faea     | c'ab( af)       | efge  (fd) d2 |
#     ((3ABc) dc  (Tdcd) ((3fga)    | ^f(gfe) d2 f | (eg)(f e)(d B)(A/2G/2) | FAAg       faec | {a}(cA)AA  (cd)       | cdec  dcAc | ((3Bcd) Ac BE (3EBc |
#          fcdc Aceg | aecA dcBA | (Tfeg) (fd) d2 |
# |1 (fgf)  fgec | ((3fga) ef       dcBA  | (TBA)Bc (Tgfed) | ((3cBA) (eA) f2 (ea) | e^def gfef | edgB A2 (AE) |
#        (FG) AG ((3BAG) A2 ((3Bcd) | e(f{e}d2 cA) Bcde | f2 (fd) gfec |   dcBA  TGFED    |
# (TBA D)(DE)   FAFA  | D(D)(FE)  D2 (EG) | FGEF D2 (dc) | BdBG (3(ABc) AF | G2 GG G2 :|
# |: (d>e) | f2 ed e2 f2 | a2 g2 f2 ef         g2 ef g2   ag    fgaf      gfed           BcdB | cAAB         ((3cBA) | BAG A2 G |
#      EDE G2 A BGE | D2 D EDB, A,D  | A,>B, A,2 A, |
# Bdc A2G G2d | (ded) (dcA) | B2 A G2 D G-e |]
#
# X:1130
# T:Erlles'
# N:.se fissing fiss, (9) (of)g2|
# (3fga fd ecA"((3A/B/c/=e}d)cd (3(efg) (3(ded) (3(cdc)|\
# | B>(A (3{A}(.E.F) {A}(GF)EF | D(3Bcd F>AD>FA>d | (3efe f>d e>cA>G |
# (3(A,B,) A,2 D/E/F/A/ BAcB|A>DDE FDGF|(C>DF) G2A|(BdcA) (FGA)|Sd2(Ad) faaf|edcB A2 (fa)|T(gf)(ed) (fd) (de) cAcE|((3ddd) (fd) ecAG|EFGA T(BA) A2||
# A2|(A(fed) ecAG|(D<(FD) (E<A) DC|(DF)(FA) (Gd)de|((3fed) ef ((3efe) ce|
# fdad fdfd|  ((3(faf) df a2 (Af) | gfec     defg   | aged           e2 (fg) | ((3agf) ec         (fd) :|2 (d<(e {g}fagf) eaaf | gece dcBA |
#           fcAag afed | cAec    cBAB  | ^c2  dA  A2     ||
#    B    | eceg       agfe | fafd      ecAg   | fef    geeg    | fedf   ec  cd   |
#          Bcde  fgef | gfge   fedc | B2 G2 G2 (cd) | efed cA A2 ||
# a2 ((3edc) ((3BcB) | (EA)AB (cB) A2 |   BcAc       Beef     e2 g2         |  efge   edeg |  ((3gfe) ((3fed) ((3cBA) | ((3cBA) ((3BA^G) (A3 G) (G>A) | B>A ((3BAE) A2 ((3AGE) | GABG A2 G2    :|
# e3 (dB) (AB) | TG2 A2 B2 B2   | ~B2 (gf) e2 (ag)  | f2 (fa) gfe^d | ((3efe) ((3gee) d(BAB) | (GE) (DE)    (GF) G   | (AG) FE FE    | DEFD    ECCE                                   | (Ac)ee  faea       | baff e- d2     |]
#
# X:1450"TTiish Aoner
# M:C
# L:1/8
# N:"collected by Cronin"
# B:O'Neill's 1560
# M:C|
# K:D
# ((3ABc)|dAFA GBAG|FADF GBAG|FAdf {a}g2 (bg)|(af)(ge) fdfd|((3ABc) GA ((3Bcd) AF | D(~EF)(ED) D2       :|
# |: (Bd) | f(a{b}a)f  gfed  |  ((3Bcd) AG  FGAc | B2 {B}AG     E2  (GE) |
# D2 ((GA) B-c dB | cA Bc d2 ge | dB  BA A2 |]
#
# X:1494
# T:Crosing the Vad
# M:C|
# L:1/8
# N:"collected by J. O'Neill"
# B:O'Neill's 1775
# R:Hornpipe
# N:"2nd Setting."
# B:O'Neill's 1713
# R:Hornpipe
# Z:"Transcribed by Bob Safranek, rjs@gsp.org"
# K:G
#    d | e3 d ((3efe) ce | d2 d2 d2 (cB) | c2 (dg) ed (c/B/)(A/G/) | B2 gB     efge    |  d2 B(G G)EG/2-A/2 |
# B dg Gg BG | eA BA FA | BGGA      GABc | dcdf ecAG        |\
#    BGBd  cBAG  |  Beed            cBce   | dfba bagf | edef                              efge| dBGB A2     |]
#
# X:1454
# T:Feash The Stilly's Hornpipe
# M:6/8
# L:1/8
# B:O'Neills 1661
# N:"collected by Gillan"
# Z:transcribed by John B. Walsh, walsh@math.ubc.ca 8/23/96
# M:C|
# L:1/8
# K:D
# FDAD dD BD|ABcA BG G2 Hx:|
# (

# %% [markdown]
# ## Part 1 - Generated Tunes
#
# Shown below are some of the sample tunes generated.
# One part of the work was to manually extract musical score and then convert from .abc format to .MIDI format.
# This I did for several tunes (which are all included in the resulting .zip file).
#
# ### Workflow
# - Manually extract .ABC files
# - Convert from .ABC format to .MIDI format using **abc2midi**
# - Convert from .MIDI format to .ogg or .WAV format using **timidity**
# - Play the .MIDI or .ogg format
#
# Here are a few samples

# %%
## Samples
X_1485 = 'x-1485'
X_10181 = 'x-10181'
X_1446 = 'x-1446'
X_1545 = 'x-1545'

# %% [markdown]
# ### Sample X-1485 - a fast, foot tapping melody
#
# As seen below, this melody has a fast 1/16 beat in 2/4 combination.  Click on the triangular button to hear it.

# %%
# Sample X-1485
with open(X_1485 + '.abc', 'r') as fin:
    t = fin.read()
    print(t)
# Play the Ogg file
Audio(X_1485 + '_abc.ogg')
# Out:
# X:1485
# T:Give Us Another
# R:reel
# N:"collected from J. O'Neill"
# B:"O'Neill's Dance Music of Ireland, 1489"
# T: roan ao dailin lon-bara., Tag
# M:2/4
# L:1/16
# N:"collected by J. O'Neill"
# B:O'Neill's 1773
# R:Hornpipe
# Z:"Transcribed by Bob Safranek, rjs@gsp.org"
# Z:Ornaments (~) in bars 4, 1/99"
# N: "Very slow and peartping herses-torday"
# B:"O'Neill's Dance Music of Ireland, 1523"
# T: ug ad aonida.
# R:markede)
# M:3/4
# Q:145
# Z:Transcribed by Michael D. Long, 10/05/98
# K:G
# (3(DEF)|GdBG FcAF|GABG D2 DG|DGBd cAFA|GABG D2 z ||
# dg ((3{a}gfg) dgga | gdBd gdBd | eaa^f       gfeg        fdec | ((3ddd) (fd) ((3gag)   (fd) |  cA A2 (GE)     |
#    Bdg>e dcBc     d2   d2   | dfdf    (fedc        ||
# dc   | dcAG (FE) E2  |        DAcA      B2 (cB)         | Addc    Bdce    | dfed cAB{def | (F<A) (~A^G) cBAz | ^(3agf (3gfe (3edc
# (3BcB |
# (3ABA (3GFE (3DED (3CB,A, | C>B (3ABc d-c (3{d}cAF | BABc dcde | fedB AFEF :|
# e2(ae) feec | dfBf dfBf | cege fdB"SHifn"(3aec (3def g2f>g|
# e>a {b}(3aga baga|>g(ba)fge|dBcA BFAF|DFAd BA ((3A^GA)|\
# A2 (Ac) BAGF|GABc dcBA|B2 "~"(BA) "~"(fe)|"~"B3 (d/e/)|
# fef ecA|cAF EAc|faf gfe|fdf Bcd|
# ((3efg) ((33fga g2 Bc|defg agae| ((3bag) ((3agf) ((3gfe) ((3fga)| e>d ((3c B) AB | ((3ABc) dG ((3efg) ed    |\
#        cBAa  (Bb) a2       | gfed  edBd  :|2 ((3efg) ((3afe) d2 ((3EFG) | A3 B c/d/e/e/ fd e>c |
# df ((3/e/d/c/) defg | fdBA GABc | dBcA (BG) G2 |]
#                 <audio controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Sample X-10181
# Another sample, with a similar beat, but different melody, and much shorter. And this one ends quite abruptly.

# %%
with open(X_10181 + '.abc') as fin:
    t = fin.read()
    print(t)

# Play the .ogg file
Audio(X_10181 + '_abc.ogg')
# Out:
# X:10181
# T:The Ruinch Nowaxfurs
# M:2/4
# L:1/16
# R:Hornpipe
# N:"2nd Setting.
# B:O'Neill's Music of Ireland
# N:The ories at ed
# N:Setting
# N:Collected by Kennedy
# Z:Transcribed by Michael D. Long, 10/06/98
# K:G
# (3(DEF)|G2GG G2 GG G2 ((3GAG) | B-cdB G2 (ef) | Tgfec dBcA | G2 G2 E2 (DE) |
# G2 ed (edB=G) | (gf/e/) .d(c) AG | (GG) GBdg|
#  ((3efg) ((3(aefg) dBAF | G2 GG G2 :|
#  |: (dc) | BAGB dcBA | GFGA B2 (cB) | AD (3FED FADF    | (TFGFE)  (DEFG) |A2 ((3Be^d) e2 e2  |]
#                 <audio controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Sample X-1446
#
# This sample is another fast melody, and also ends abruptly. The Title is meh, and some of the notes do not make sense.

# %%
# Sample X-1446
with open(X_1446 + '.abc') as fin:
    t = fin.read()
    print(t)

# Play the .ogg file
Audio(X_1446 + '_abc.ogg')
# Out:
# X:1446
# T:Pretty Blorinaal?
# M: 2/4
# L: 1/16
# N:"collected by F. O'NEIL
# Z:Transcribed by A.LEE WORMAN
# K:G
# (dc)|BGA^F G2 E-A-B-c|
# AGA2 E2 (A/B/) | cdcd efge | ((3fga) ef              dcBA    | GBAG   FD    TD   |
#    Bc ((3efg)    (((3fed) d2 | Hf4 ((f/{a}fe)a T(f<a) g2 | ((3efg)  eiged          ((3BcB) (AB) | (cB) Ac    edfe     |  ((3fga)
# ec d2      ||
#        Bc       fdfa gfga | bgfg edBG | A^GAB T(ED) E2  \
# | (fgab)a2 (gf)(ea) | ==gfge   dgBg     | ((3gab) af e2 (ea) |       (ga)gf e(e {a}(3gfg | dz ((3gfe) ((3fed) | ddfe
# fdef |1 T((3gab) (eg) baaf                                  (((3gfe) e>f z d gfge | a2 ((3aba) {g}fe"d3 ||
#                 <audio controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### All Generated Sample Music
#
# All of the generated output is in the current directory in .abc and .ogg files.

# %% [markdown]
# ## Part 2 - Generate Bob Dylan Lyrics
#
# On to the bonus part - generating Bob Dylan lyrics.
#
# Using a small corpus (~713KB) of Bob Dylan songs, an LSTM network was trained with 3 layers, and 256 cells in each layer.
#
# The results are below.

# %%
## Generate Bob Dylan lyrics using pre-trained model

with open(BOB_DYLAN_TXT, "r") as fin:
    dylan_txt = fin.read()
    
print("Dylan corpus length: ", len(dylan_txt))
# Out:
# Dylan corpus length:  702382

# %%
print(dylan_txt[0:200])
# Out:
# 10,000 Men
# Written by: Bob Dylan
#
# Ten thousand men on a hill
# Ten thousand men on a hill
# Some of ’m goin’ down, some of ’m gonna get killed
#
# Ten thousand men dressed in oxford blue
# Ten thousand men dr

# %%
# Model params -- must be the same as those used to train the model!
n_layers = 3
n_cells = 256
model_type = 'lstm'
learning_rate = 0.001   # even if we dont need this 
ckpt_name = '1-dylan.ckpt-49900'
gradient_clip = 5.0

# %%
## Generate some Dylan lyrics!

output = infer(dylan_txt,
              ckpt_name,    # ensure correct checkpoint name!
               5000,  # num of iterations to run for; num of characters to generate
              n_cells=n_cells,
              n_layers=n_layers,
              gradient_clip=5.0,
              learning_rate=learning_rate,
              sampling='prob')
# Out:
# ### About to infer...
# ### Model restored:  1-dylan.ckpt-49900
# Can’t you be a fool I did before
# It ain’t eyes, I see my baby now
# You can take ahold made coal
# In the will of coats and flows
# The rain Geliver
# That’s the day you die, Lawd, Law Louls Auton
# But I don’t feel all in ling
# In my captain her skinness of the line
# But I don’t see where we weren’t put me down
# Come you so bad on
# To the Tude that you can do
# I might have been cooking back to me
#
# I got the man with the stage fright,
# Just to be a man and chain the shore
# I hear that sometimes Satan comes as a man of peace
#
# He got a sweet gift of gambler neits
# The lonesome freight to prove?
#
# ============= Copyright © 1965 by Warner Bros. Inc.; renewed 1993 by Special Rider Music
#
# Precious Memories
#
# Written by: Bob Dylan (arr)
#
# No more, no more
# No more pint of stoppin' at the right quick was gone
# All I have and all I see are right to me, baby
# I’ll do right to your head faces
# Don’t feel bad, no, night are no pain
# Tryin’ to hold up, when you gonna wake up
# When you go now
# You can roubles
# Lookin’ at the sons, threweding beautiful choose
# Cops and hangin’ like a hopper whicker fitules
# Mother, no man sees my face
# The morning dust your money was green
#
# Didn’t I rise above my head, so many
# He’s younger for the places to the ground
# You know what they pass the earth an’ I am hurt
# I didn’t know what it is
# But I didn’t realize in her honey
# I was just a little humilled with a fire
# I can cry for pays this mumberial
# Blessiry father’s kiss
# Spening his lagows, it’s just as soon as the dark clouds lift
# Gonna break the rooms of the street
# I am homeless, come and take me
# Into the ottone you when you’re with me
#
# I got the heart and it dandy came to be this way
# What happened to the reason to a fool and how I far away
#
# One more weekend, one more weekend’ll do
#
# ============= Copyright © 1967, 1970 by Dwarf Music; renewed 1995, 1998 by Dwarf Music; renewed 1995, 1998 by Special Rider Music
#
# Ragged & D. Herrord
#
# I didn’t know what it is
# Do you, Mister Jonk strong for a while
#
# He’s the bright light of salr
# I hear the broken heart
# The days I’ll take all the right passing beater that it means.
#
# ============= Copyright ©1993 Special Rider Music
#
# Ragged & Dirty
#
# Written by: Bob Dylan (arr)
#
# 1.Was in the summer,
# On the rain is, the kerose-sitt
# They were scaredalls can go
#
# The truth was swimmin’
# Who are you that hide before
# But I ain’t gonna hear it said no more
#
# “Oh, stomm, I’m as I go for bar
# The petal we go now, my blue-eyed You a-gonna make me
# And it’s only time they say I shot the blues
# Ev’ry night in a Pain
#
# He would not be changed
#
# The priest in chimes
# On a corner I’m not Highing and the rifles in the hall
# How can I deal like new she's gone I slowly die
#
# ============= Copyright © 1966 by Dwarf Music; renewed 1994 by Dwarf Music
#
# Po’ For You
#
# Written by: Bob Dylan
#
# Seven days, seven more days that are connected
# Just like I ever did too much Up a hundred miles
#
# I’m crospin’ my chains,
# I got this fauntured your eyes.
#
# 3.Frankie we'll be there
# The judge made in Mississippi, wanted me to be
#
# ============= Copyright © 1963 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# R. I Don’t Huy Best
#
# Written by: Bob Dylan and Robert Town, her fawn frother
# Look out in your cards
# He headed to lazy rich dream
# It’s not dark yet, but it’s getting there
#
# The cat’s in the well and the servant is always levgin’ her name could be kind
# So giving the devil
# But I'm ready to go anywhere, I’m ready for to fade
# In this rag, Uh-huh,
# Can't you hear to you, you don’t sell down on this tree
# There’s a certain things a teal with this
# But I did it, thick you was all right
# Most of the time
#
# ============= Copyright © 1982 by Special Rider Music
#
# Stack A Leeted & The First None And You Haven no Kos
#
# Written by: Bob Dylan
#
# Oxford Town, Oxford Town
# Ev’rybody’s got but there’s one time, I took me I was doin’ fire
# But the mouse we can salls the wall
# Swing to kill back to Col you First-lege
# And they set him on a hill
# The gold to cry Arthood!
#
# ============= Copyright © 1973 by Ram's Horn Music
#
# One More Publing
#
# Written by: Bob Dylan
#
# Can’t you hear to your face
# For now’s the time if I can tried you faite
# Potienals in cash of Cacking
# Better stay’s love with a path when I’m dead
# No one don’t unded it into thinking
# That the fifth Sky Moultor and die to the top of the hill
#
# Oh, I miss my baby
# Somebody is out there beating a dead him on the scene
# Situation, was through the blinds, time ago
#
# Catfish, million worm for your personalmising force
# She saw her son about ya love is my feet sixions
# Lord, protect my child
#
# One says, “My advice is the battlegeress, come thring
# From top of the room
# Where my love and I. make the desert stone way.
#
# ============= Copyright ©
#
# Standing Hearts
#
#
# Mississippis call A Word
#
#
#
# Oxford Town
#
# Written by: Bob Dylan
#
# Ol’ behind the that’s in mind, babe
# I can't be good no more, once like I did before."
# My babies on the mountain, of crold be known
# I told you and find some thing it would ever show you the voices mostering sun
# Called sigh that rag of the midni(5001,)
#
# Can’t you be a fool I did before
# It ain’t eyes, I see my baby now
# You can take ahold made coal
# In the will of coats and flows
# The rain Geliver
# That’s the day you die, Lawd, Law Louls Auton
# But I don’t feel all in ling
# In my captain her skinness of the line
# But I don’t see where we weren’t put me down
# Come you so bad on
# To the Tude that you can do
# I might have been cooking back to me
#
# I got the man with the stage fright,
# Just to be a man and chain the shore
# I hear that sometimes Satan comes as a man of peace
#
# He got a sweet gift of gambler neits
# The lonesome freight to prove?
#
# ============= Copyright © 1965 by Warner Bros. Inc.; renewed 1993 by Special Rider Music
#
# Precious Memories
#
# Written by: Bob Dylan (arr)
#
# No more, no more
# No more pint of stoppin' at the right quick was gone
# All I have and all I see are right to me, baby
# I’ll do right to your head faces
# Don’t feel bad, no, night are no pain
# Tryin’ to hold up, when you gonna wake up
# When you go now
# You can roubles
# Lookin’ at the sons, threweding beautiful choose
# Cops and hangin’ like a hopper whicker fitules
# Mother, no man sees my face
# The morning dust your money was green
#
# Didn’t I rise above my head, so many
# He’s younger for the places to the ground
# You know what they pass the earth an’ I am hurt
# I didn’t know what it is
# But I didn’t realize in her honey
# I was just a little humilled with a fire
# I can cry for pays this mumberial
# Blessiry father’s kiss
# Spening his lagows, it’s just as soon as the dark clouds lift
# Gonna break the rooms of the street
# I am homeless, come and take me
# Into the ottone you when you’re with me
#
# I got the heart and it dandy came to be this way
# What happened to the reason to a fool and how I far away
#
# One more weekend, one more weekend’ll do
#
# ============= Copyright © 1967, 1970 by Dwarf Music; renewed 1995, 1998 by Dwarf Music; renewed 1995, 1998 by Special Rider Music
#
# Ragged & D. Herrord
#
# I didn’t know what it is
# Do you, Mister Jonk strong for a while
#
# He’s the bright light of salr
# I hear the broken heart
# The days I’ll take all the right passing beater that it means.
#
# ============= Copyright ©1993 Special Rider Music
#
# Ragged & Dirty
#
# Written by: Bob Dylan (arr)
#
# 1.Was in the summer,
# On the rain is, the kerose-sitt
# They were scaredalls can go
#
# The truth was swimmin’
# Who are you that hide before
# But I ain’t gonna hear it said no more
#
# “Oh, stomm, I’m as I go for bar
# The petal we go now, my blue-eyed You a-gonna make me
# And it’s only time they say I shot the blues
# Ev’ry night in a Pain
#
# He would not be changed
#
# The priest in chimes
# On a corner I’m not Highing and the rifles in the hall
# How can I deal like new she's gone I slowly die
#
# ============= Copyright © 1966 by Dwarf Music; renewed 1994 by Dwarf Music
#
# Po’ For You
#
# Written by: Bob Dylan
#
# Seven days, seven more days that are connected
# Just like I ever did too much Up a hundred miles
#
# I’m crospin’ my chains,
# I got this fauntured your eyes.
#
# 3.Frankie we'll be there
# The judge made in Mississippi, wanted me to be
#
# ============= Copyright © 1963 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# R. I Don’t Huy Best
#
# Written by: Bob Dylan and Robert Town, her fawn frother
# Look out in your cards
# He headed to lazy rich dream
# It’s not dark yet, but it’s getting there
#
# The cat’s in the well and the servant is always levgin’ her name could be kind
# So giving the devil
# But I'm ready to go anywhere, I’m ready for to fade
# In this rag, Uh-huh,
# Can't you hear to you, you don’t sell down on this tree
# There’s a certain things a teal with this
# But I did it, thick you was all right
# Most of the time
#
# ============= Copyright © 1982 by Special Rider Music
#
# Stack A Leeted & The First None And You Haven no Kos
#
# Written by: Bob Dylan
#
# Oxford Town, Oxford Town
# Ev’rybody’s got but there’s one time, I took me I was doin’ fire
# But the mouse we can salls the wall
# Swing to kill back to Col you First-lege
# And they set him on a hill
# The gold to cry Arthood!
#
# ============= Copyright © 1973 by Ram's Horn Music
#
# One More Publing
#
# Written by: Bob Dylan
#
# Can’t you hear to your face
# For now’s the time if I can tried you faite
# Potienals in cash of Cacking
# Better stay’s love with a path when I’m dead
# No one don’t unded it into thinking
# That the fifth Sky Moultor and die to the top of the hill
#
# Oh, I miss my baby
# Somebody is out there beating a dead him on the scene
# Situation, was through the blinds, time ago
#
# Catfish, million worm for your personalmising force
# She saw her son about ya love is my feet sixions
# Lord, protect my child
#
# One says, “My advice is the battlegeress, come thring
# From top of the room
# Where my love and I. make the desert stone way.
#
# ============= Copyright ©
#
# Standing Hearts
#
#
# Mississippis call A Word
#
#
#
# Oxford Town
#
# Written by: Bob Dylan
#
# Ol’ behind the that’s in mind, babe
# I can't be good no more, once like I did before."
# My babies on the mountain, of crold be known
# I told you and find some thing it would ever show you the voices mostering sun
# Called sigh that rag of the midni

# %% [markdown]
# ## Generate some more Bob Dylan lyrics

# %%
## Generate Bob Dylan lyrics using pre-trained model

with open(BOB_DYLAN_TXT, "r") as fin:
    dylan_txt = fin.read()
    
print("Dylan corpus length: ", len(dylan_txt))
# Out:
# Dylan corpus length:  702382

# %%
# Model params -- must be the same as those used to train the model!
n_layers = 3
n_cells = 256
model_type = 'lstm'
learning_rate = 0.001   # even if we dont need this 
ckpt_name = '1-dylan.ckpt-49900'
gradient_clip = 5.0

## Generate some Dylan lyrics!

output = infer(dylan_txt,
              ckpt_name,    # ensure correct checkpoint name!
               8000,  # num of iterations to run for; num of characters to generate
              n_cells=n_cells,
              n_layers=n_layers,
              gradient_clip=5.0,
              learning_rate=learning_rate,
              sampling='prob')
# Out:
# ### About to infer...
# ### Model restored:  1-dylan.ckpt-49900
# Seven yourself, don't you exish she could early papers will you serve them to me?"
#
# Well they took me down town  and they dressed me in black,
# They put me on a train and they sent me back..
#
# Dear Katie,
# If you ever do is too bad
# He can do it kicls that you’re finally for?
#
# Oh we’re always shine like a truck
# The house and watch the brazing greatened, they had my unworp
# And my working back to flort
# Where the earth jewiles from my head full of my hand
# And rivers that falling down
# If it for the country bunded down to the ground
# You know if you didn't win
# But let me just warn in a laud him down
# All night long down
# All the next mornin’ she had awoken
# To know that the judge had never say hello, she might be what they mean that held it steal
# For him hangin’ dry sigh to the end
# I'm going to do what the light
# Don’t want you to
#
# Now you’re here before I turn you when you walk all alone
# They’ll stone you when you’re riding in your car
# They say that Cany’s Cut of waigh
# When dis Of Me
#
# Written by: Frank ScAUhalloh down.
# Lord, Lord
# They cut Ready for taken
#
# Shot it into the doors and the ring
# When the mouse and things
# I’m gonna go down to Catceon
# As he was fear to come to be kind
# Now I haveng mind
# And we came to the book
# The place ain’t nothin' let or later, oh, oh
# That the doctor was were rision secret me to talk
# But a fort stand in my sinna woman like
#
# I believe I'm fivin’ the rising sun return
# Sooner or later you too shall burn
#
# The night's filled with shadows, their mothers were grassber
# You walked around for a while
#
# The games Joyans a boat would ever cane it could I be not to do
# And hope you told me
# To stand ‘rong back to Colorado, I want to ento others
# And it candy dead to me
# And passing from the county seat from a man of stone
#
# You can laugh at salvation, you can play Olympic Bab.
#
# ============= Copyright ©1992 Special Rider Music
#
# Neighborhood Bully
#
# Written by: Bob Dylan
#
# Instrumental
#
# ============= Copyright © 1973 by Ram's Horn Music
#
# One More Nine
#
# Written by: Bob Dylan
#
# I got mixed up ev’rything, eaching my head
#
# Corrina, Corrina
# Get clouds away from your face
# You can be a sweet ball at clothes
# But lately I see her kindly
# When the children were babies and played on the beanfixed with my eyes
# The other shuck sails are dreamed of her father's need
# You tell me quick with a glove
# For the line has louder they would dest it
# In a villuw and paid Frankie Lee
#
# ============= Copyright ©1978 MCA
#
# My Wife’s Home Town
#
# Written by: Bob Dylan and Jacques Levy
#
# Hot chili peppers in the blistering sun
# Dust on my face and my cape
# Me and Magdalena on the run
# I think this time we shall escape
#
# Sold my guitar to the baker’s son
# You can’t let go to Was still your friends
# Look away, you rollin' roulend by
# I feel pumping at the ’lacume is straight
# And I dropped my mind when I tried to get closedned through her chased have like the bloody fate
# Which sappition hus by the shall
# What are leavin’ in the world, Lord, Lord
# They cut George Jackson down
# Lord, Lord
# They cut George Jackson
# Standin’ next to Collo
# Come and life or dignity?
#
# You know I can’t sleep a wayfory, come between Fe
# Nothing that I wouldn’t do
# Go in the great underneath his not view
# I stole away and I had to realishing—and suppet for a picnic sure it down
# So well to my pick
# “ev’rybody seemed to be a rank stranger
# No mother or dad not a friend could I see
# They knew not my name and I knew not their faces
# I found they were all rank strangers to me.
#
# They all moved a way, said a carned a Jime for the ones that I go
# Somebody said from the Bible he’l turn her face
#
# Well, I leave her out in your castle, Uh-huh
#
# Hald Like A Rublor-
# Every riding of my mind
# I can't stay up in drivented
# Or if I was with you to try to protect your identity?
# She goes with the land to fied ’em
# That the wild so exploytmard and I ain’t sureed
# Every hand’rine it was hangin’ day
# I was burned out from exhaustion, buring in the alley
# Fighting every incrief
#
# Everybody get ready to the carnival tonight
# On Desolation Roy.
#
# ============= Copyright ©1962; renewed 1990 2004 Special Rider Music and Ice-Nine Publishing
#
# Lily, Seen your name And Baby In Schmi
#
# Written by: Bob Dylan
#
# No use and drink me down my way
# Like a fool you're gonna hear me say:
# "I'll lay at your bed Sally Sue Brown
# Please feel the heat of smoke, past testing will be tough
# Sally says, "You can take ahold me in the Orluts up above the triails humin to try to call him a isen’tility my trap foot
# But I know what you’d tell them to the fallout ship that drifted merch or beast creed
# I a-seak of this land is your land, this land is my land
# From California to the New York Island
# From the redwood forest to the gulf straight-maid
# I was a-halfitten that he did disappears
# Up the steps into the nearest bank
#
# ============= Copyright © 1975, 1976 by Ram's Horn Music; renewed 2003, 2004 by Ram’s Horn Music
#
# Lily Of The Door
#
# Written by: Bob Dylan
#
# A wore that beld highdal cow
# I’m twenty miles from you
#
# I need your crumbling in the end
# Tryin’ to be a new frighter,
# Just tell him like a traveling
# As the ruin believin’ me
#
# Can't every hair you forgive me, you stand I’m askin’
# I was raising the way she left him snous
# And send you but I can only feel that I am
# When I asked him to my home
# To my home, Lord, to use your friends
# Louds of the curture
# In Mississippi, talth its all swing
# Can make the high Skiins
# Where you are here and step into the life that wouldn't come señor
# I said about the man she could see him, but I don’t know who has eternion and love just like I
# And I can’t tell Her If I just did not feel so all alone
#
# ============= Copyright © 1965 by Warner Bros. Inc.; renewed 1993 by Special Rider Music
#
# Po’ Land The Dun Of Flide
#
# Written by: Bob Dylan
#
# Oh, you can read out your Bible
# You can fall down on your knees, pretty mama
# And pray to the Lord
# But it ain’t gonna do no good
#
# You’re gonna need
# You’re gonna need my help someday
# Well, if you can’t quit your sinnin’
# Please quit your low down ways
#
# Oh, you can read out your Bible
# You can fall down on your knees, pretty mama
# And pray to the High Skying on his mind
# Little rooster crowin’, there must be something
#
# So name to sleep ramblin’ sky
# My eyes they start to find some beautiful people ever could not reach
# There’s no books upon your shelf
# And your place till you die
# What good am I?
#
# What good am I the Jack of Hearts
#
# No one’s not the earthh in the / Jach up Musta Mary Lord
#
# Written by: Bob Dylan
#
# Peggy Day stole my poor heart away
# By golly, what more can I say
# Love to the engine leaves far away
#
# Oh, darlin’, can we keep it between resver
# It’s unbelievally was then to see the frozen rule
#
# ============= Copyright © 1964, 1966 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# Pay In Blood
#
# Written by: Bob Dylan
#
# Click the 'VIEW ALL' link at the right to see a list of Bob Dylan's live performances of this song.
# On a Rainy Afternoon
#
# Written by: Bob Dylan
#
#
# One Too Mories,
# When Royes
#
#
# I Dreamed I Saw St. Augustine
#
# Written by: Bob Dylan
#
# Mm, tell mama
# Where’d ya sleep last night?
# Cain’t ya hear me cryin’?
# Hm, hm, hm
#
#
# ============= Copyright
#
# ============= Copyright © 1969 Big Sky Music and Harrisongs Music
#
# Poor Darkin’
#
# Written by: Bob Dylan
#
# Come around you road somehow
# No match is inder many black stairs on your well
#
# We live in a political world
# Where peace is not weary
# Like Artol
#
# ============= Copyright © 1964 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# Tomorrow, I said
# “Can the streets of my mind
# Night after night another bottle finds a hill
# She was on the other so imbermain
# You can do about it ain’t got it
# That’s not a friend could I see
# They keep him in a truck in a man.
#
# ============= Copyright © 1967, 1970 by Dwarf Music; renewed 1995 by Dwarf Music
#
# Pledging My Town
#
# Written by: Bob Dylan
#
# Oxford Town
#
#
# Our control
#
# Written by: Bob Dylan
#
# Slippin’ and slidin’ like a weas, it surely giel
# It’s a shame to your childhood
# Or friends I said to the throat,
# "I ain't paid no which is all right, I ju(8001,)
#
# Seven yourself, don't you exish she could early papers will you serve them to me?"
#
# Well they took me down town  and they dressed me in black,
# They put me on a train and they sent me back..
#
# Dear Katie,
# If you ever do is too bad
# He can do it kicls that you’re finally for?
#
# Oh we’re always shine like a truck
# The house and watch the brazing greatened, they had my unworp
# And my working back to flort
# Where the earth jewiles from my head full of my hand
# And rivers that falling down
# If it for the country bunded down to the ground
# You know if you didn't win
# But let me just warn in a laud him down
# All night long down
# All the next mornin’ she had awoken
# To know that the judge had never say hello, she might be what they mean that held it steal
# For him hangin’ dry sigh to the end
# I'm going to do what the light
# Don’t want you to
#
# Now you’re here before I turn you when you walk all alone
# They’ll stone you when you’re riding in your car
# They say that Cany’s Cut of waigh
# When dis Of Me
#
# Written by: Frank ScAUhalloh down.
# Lord, Lord
# They cut Ready for taken
#
# Shot it into the doors and the ring
# When the mouse and things
# I’m gonna go down to Catceon
# As he was fear to come to be kind
# Now I haveng mind
# And we came to the book
# The place ain’t nothin' let or later, oh, oh
# That the doctor was were rision secret me to talk
# But a fort stand in my sinna woman like
#
# I believe I'm fivin’ the rising sun return
# Sooner or later you too shall burn
#
# The night's filled with shadows, their mothers were grassber
# You walked around for a while
#
# The games Joyans a boat would ever cane it could I be not to do
# And hope you told me
# To stand ‘rong back to Colorado, I want to ento others
# And it candy dead to me
# And passing from the county seat from a man of stone
#
# You can laugh at salvation, you can play Olympic Bab.
#
# ============= Copyright ©1992 Special Rider Music
#
# Neighborhood Bully
#
# Written by: Bob Dylan
#
# Instrumental
#
# ============= Copyright © 1973 by Ram's Horn Music
#
# One More Nine
#
# Written by: Bob Dylan
#
# I got mixed up ev’rything, eaching my head
#
# Corrina, Corrina
# Get clouds away from your face
# You can be a sweet ball at clothes
# But lately I see her kindly
# When the children were babies and played on the beanfixed with my eyes
# The other shuck sails are dreamed of her father's need
# You tell me quick with a glove
# For the line has louder they would dest it
# In a villuw and paid Frankie Lee
#
# ============= Copyright ©1978 MCA
#
# My Wife’s Home Town
#
# Written by: Bob Dylan and Jacques Levy
#
# Hot chili peppers in the blistering sun
# Dust on my face and my cape
# Me and Magdalena on the run
# I think this time we shall escape
#
# Sold my guitar to the baker’s son
# You can’t let go to Was still your friends
# Look away, you rollin' roulend by
# I feel pumping at the ’lacume is straight
# And I dropped my mind when I tried to get closedned through her chased have like the bloody fate
# Which sappition hus by the shall
# What are leavin’ in the world, Lord, Lord
# They cut George Jackson down
# Lord, Lord
# They cut George Jackson
# Standin’ next to Collo
# Come and life or dignity?
#
# You know I can’t sleep a wayfory, come between Fe
# Nothing that I wouldn’t do
# Go in the great underneath his not view
# I stole away and I had to realishing—and suppet for a picnic sure it down
# So well to my pick
# “ev’rybody seemed to be a rank stranger
# No mother or dad not a friend could I see
# They knew not my name and I knew not their faces
# I found they were all rank strangers to me.
#
# They all moved a way, said a carned a Jime for the ones that I go
# Somebody said from the Bible he’l turn her face
#
# Well, I leave her out in your castle, Uh-huh
#
# Hald Like A Rublor-
# Every riding of my mind
# I can't stay up in drivented
# Or if I was with you to try to protect your identity?
# She goes with the land to fied ’em
# That the wild so exploytmard and I ain’t sureed
# Every hand’rine it was hangin’ day
# I was burned out from exhaustion, buring in the alley
# Fighting every incrief
#
# Everybody get ready to the carnival tonight
# On Desolation Roy.
#
# ============= Copyright ©1962; renewed 1990 2004 Special Rider Music and Ice-Nine Publishing
#
# Lily, Seen your name And Baby In Schmi
#
# Written by: Bob Dylan
#
# No use and drink me down my way
# Like a fool you're gonna hear me say:
# "I'll lay at your bed Sally Sue Brown
# Please feel the heat of smoke, past testing will be tough
# Sally says, "You can take ahold me in the Orluts up above the triails humin to try to call him a isen’tility my trap foot
# But I know what you’d tell them to the fallout ship that drifted merch or beast creed
# I a-seak of this land is your land, this land is my land
# From California to the New York Island
# From the redwood forest to the gulf straight-maid
# I was a-halfitten that he did disappears
# Up the steps into the nearest bank
#
# ============= Copyright © 1975, 1976 by Ram's Horn Music; renewed 2003, 2004 by Ram’s Horn Music
#
# Lily Of The Door
#
# Written by: Bob Dylan
#
# A wore that beld highdal cow
# I’m twenty miles from you
#
# I need your crumbling in the end
# Tryin’ to be a new frighter,
# Just tell him like a traveling
# As the ruin believin’ me
#
# Can't every hair you forgive me, you stand I’m askin’
# I was raising the way she left him snous
# And send you but I can only feel that I am
# When I asked him to my home
# To my home, Lord, to use your friends
# Louds of the curture
# In Mississippi, talth its all swing
# Can make the high Skiins
# Where you are here and step into the life that wouldn't come señor
# I said about the man she could see him, but I don’t know who has eternion and love just like I
# And I can’t tell Her If I just did not feel so all alone
#
# ============= Copyright © 1965 by Warner Bros. Inc.; renewed 1993 by Special Rider Music
#
# Po’ Land The Dun Of Flide
#
# Written by: Bob Dylan
#
# Oh, you can read out your Bible
# You can fall down on your knees, pretty mama
# And pray to the Lord
# But it ain’t gonna do no good
#
# You’re gonna need
# You’re gonna need my help someday
# Well, if you can’t quit your sinnin’
# Please quit your low down ways
#
# Oh, you can read out your Bible
# You can fall down on your knees, pretty mama
# And pray to the High Skying on his mind
# Little rooster crowin’, there must be something
#
# So name to sleep ramblin’ sky
# My eyes they start to find some beautiful people ever could not reach
# There’s no books upon your shelf
# And your place till you die
# What good am I?
#
# What good am I the Jack of Hearts
#
# No one’s not the earthh in the / Jach up Musta Mary Lord
#
# Written by: Bob Dylan
#
# Peggy Day stole my poor heart away
# By golly, what more can I say
# Love to the engine leaves far away
#
# Oh, darlin’, can we keep it between resver
# It’s unbelievally was then to see the frozen rule
#
# ============= Copyright © 1964, 1966 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# Pay In Blood
#
# Written by: Bob Dylan
#
# Click the 'VIEW ALL' link at the right to see a list of Bob Dylan's live performances of this song.
# On a Rainy Afternoon
#
# Written by: Bob Dylan
#
#
# One Too Mories,
# When Royes
#
#
# I Dreamed I Saw St. Augustine
#
# Written by: Bob Dylan
#
# Mm, tell mama
# Where’d ya sleep last night?
# Cain’t ya hear me cryin’?
# Hm, hm, hm
#
#
# ============= Copyright
#
# ============= Copyright © 1969 Big Sky Music and Harrisongs Music
#
# Poor Darkin’
#
# Written by: Bob Dylan
#
# Come around you road somehow
# No match is inder many black stairs on your well
#
# We live in a political world
# Where peace is not weary
# Like Artol
#
# ============= Copyright © 1964 by Warner Bros. Inc.; renewed 1992 by Special Rider Music
#
# Tomorrow, I said
# “Can the streets of my mind
# Night after night another bottle finds a hill
# She was on the other so imbermain
# You can do about it ain’t got it
# That’s not a friend could I see
# They keep him in a truck in a man.
#
# ============= Copyright © 1967, 1970 by Dwarf Music; renewed 1995 by Dwarf Music
#
# Pledging My Town
#
# Written by: Bob Dylan
#
# Oxford Town
#
#
# Our control
#
# Written by: Bob Dylan
#
# Slippin’ and slidin’ like a weas, it surely giel
# It’s a shame to your childhood
# Or friends I said to the throat,
# "I ain't paid no which is all right, I ju

# %% [markdown]
# ## Part 2 - Generated Bob Dylan Lyrics
#
# Some of the generated Dylan lyrics are shown below.
# The output files are called **dylan-out-n.txt** (n=1,2,3,4)

# %%
# Dylan output
d1 = 'dylan-out-1.txt'
d2 = 'dylan-out-2.txt'
d3 = 'dylan-out-3.txt'
d4 = 'dylan-out-4.txt'

# %%
# Dylan 1
with open(d1, "r") as fin:
    t = fin.read()
    print(t)
# Out:
# Dear Katie,
# If you ever do is too bad
# He can do it kicls that you’re finally for?
#
# Oh we’re always shine like a truck
# The house and watch the brazing greatened, they had my unworp
# And my working back to flort
# Where the earth jewiles from my head full of my hand
# And rivers that falling down
# If it for the country bunded down to the ground
# You know if you didn't win
# But let me just warn in a laud him down
# All night long down
# All the next mornin’ she had awoken
# To know that the judge had never say hello, she might be what they mean that held it steal
# For him hangin’ dry sigh to the end
# I'm going to do what the light
# Don’t want you to
#
# Now you’re here before I turn you when you walk all alone
# They’ll stone you when you’re riding in your car
# They say that Cany’s Cut of waigh
# When dis Of Me
#
# Written by: Frank ScAUhalloh down.
# Lord, Lord
# They cut Ready for taken
#
# Shot it into the doors and the ring
# When the mouse and things
# I’m gonna go down to Catceon
# As he was fear to come to be kind
# Now I haveng mind
# And we came to the book
# The place ain’t nothin' let or later, oh, oh
# That the doctor was were rision secret me to talk
# But a fort stand in my sinna woman like
#
# I believe I'm fivin’ the rising sun return
# Sooner or later you too shall burn
#
# The night's filled with shadows, their mothers were grassber
# You walked around for a while
#
# The games Joyans a boat would ever cane it could I be not to do
# And hope you told me
# To stand ‘rong back to Colorado, I want to ento others
# And it candy dead to me
# And passing from the county seat from a man of stone
#
# You can laugh at salvation, you can play Olympic Bab.
#
# ============= Copyright ©1992 Special Rider Music

# %%
# Dylan 2
with open(d2, "r") as fin:
    t = fin.read()
    print(t)
# Out:
# My Wife’s Home Town
#
# Written by: Bob Dylan and Jacques Levy
#
# Hot chili peppers in the blistering sun
# Dust on my face and my cape
# Me and Magdalena on the run
# I think this time we shall escape
#
# Sold my guitar to the baker’s son
# You can’t let go to Was still your friends
# Look away, you rollin' roulend by
# I feel pumping at the ’lacume is straight
# And I dropped my mind when I tried to get closedned through her chased have like the bloody fate
# Which sappition hus by the shall
# What are leavin’ in the world, Lord, Lord
# They cut George Jackson down
# Lord, Lord
# They cut George Jackson
# Standin’ next to Collo
# Come and life or dignity?
#
# You know I can’t sleep a wayfory, come between Fe
# Nothing that I wouldn’t do
# Go in the great underneath his not view
# I stole away and I had to realishing—and suppet for a picnic sure it down
# So well to my pick
# “ev’rybody seemed to be a rank stranger
# No mother or dad not a friend could I see
# They knew not my name and I knew not their faces
# I found they were all rank strangers to me.
#
# They all moved a way, said a carned a Jime for the ones that I go
# Somebody said from the Bible he’l turn her face
#
# Well, I leave her out in your castle, Uh-huh
#
# Hald Like A Rublor-
# Every riding of my mind
# I can't stay up in drivented
# Or if I was with you to try to protect your identity?
# She goes with the land to fied ’em
# That the wild so exploytmard and I ain’t sureed
# Every hand’rine it was hangin’ day
# I was burned out from exhaustion, buring in the alley
# Fighting every incrief
#
# Everybody get ready to the carnival tonight
# On Desolation Roy.
#
# ============= Copyright ©1962; renewed 1990 2004 Special Rider Music and Ice-Nine Publishing

# %% [markdown]
# ## On Dylan's Lyrics
#
# Dylan's original lyrics are _deep_, imbued with meaning, raw emotions, and express the multitudes of fundamental human condition. People have written dissertations on Dylan's prolific career over the past five decades. I'm not about to repeat that. :-)
#
# *The RNN-generated lyrics are _deep_ only in the sense of the network* 🙂. While the 3-layer LSTM network does generate legitimate words, it has several problems. Many words are just plain made up; there is not much meaning when the words are correct English words. However, there is promise in generating textually correct English, even if semantically it doesn't make sense.
# My network had the limitions of training only for some 50,000 iterations on a Macbook Pro (with no GPU for Tensor Flow).

# %%
## ALL GENERATED OUTPUT
OUTPUT_DIR = "output"

all_outfiles = os.listdir(OUTPUT_DIR)
len(all_outfiles)
# Out:
# 80

# %%
print(all_outfiles[0:5])
# Out:
# ['cooleys-X51.abc', 'cooleys-X51.abc.mid', 'cooleys-X51.abc.ogg', 'cooleys-X51_abc.mp3', 'cooleys-X51_abc.ogg']

# %%
IN_FILES = [ONEILL_IRISH,
            COBBS_IRISH,
            IRISH_MUSIC,
            NOTTINGHAM_FOLK,
            BOB_DYLAN_TXT,
            '1-dylan.ckpt-49900',
            'irish.ckpt-16100',
            'Music-Lyrics-Char-RNN.ipynb',
            'Generating-Music-via-RNNs-Atul_Acharya.mp4'  # The video
            
           ]

zip_files = tuple(IN_FILES + all_outfiles)
len(zip_files)
# Out:
# 89

# %%
### Build the submission
cwd = os.getcwd() + '/'
utils.build_submission ('Atul_Acharya-CADL-Project.zip',
                       zip_files)
# Out:
# You are missing the file cooleys-X51_abc.mp3.  It does not look like you have completed Part 13.
#
# You are missing the file cooleys-X51_abc.ogg.  It does not look like you have completed Part 14.
#
# You are missing the file Generating-Music-via-CharRNN.  It does not look like you have completed Part 20.
#
# You are missing the file julia-delaney-X174.mp3.  It does not look like you have completed Part 23.
#
# You are missing the file st-annes-X322_abc.mp3.  It does not look like you have completed Part 28.
#
# You are missing the file st-annes-X322_abc.ogg.  It does not look like you have completed Part 29.
#
# You are missing the file x-10181_abc.ogg.mp3.  It does not look like you have completed Part 33.
#
# You are missing the file x-1107_abc.ogg.mp3.  It does not look like you have completed Part 37.
#
# You are missing the file x-1341_abc.ogg.mp3.  It does not look like you have completed Part 41.
#
# You are missing the file x-1388_abc.ogg.mp3.  It does not look like you have completed Part 45.
#
# You are missing the file x-1430_abc.ogg.mp3.  It does not look like you have completed Part 49.
#
# You are missing the file x-1440_abc.ogg.mp3.  It does not look like you have completed Part 53.
#
# You are missing the file x-1444_abc.ogg.mp3.  It does not look like you have completed Part 57.
#
# You are missing the file x-1446_abc.ogg.mp3.  It does not look like you have completed Part 61.
#
# You are missing the file x-1450_abc.ogg.mp3.  It does not look like you have completed Part 65.
#
# You are missing the file x-1480_abc.ogg.mp3.  It does not look like you have completed Part 69.
#
# You are missing the file x-1485_abc.ogg.mp3.  It does not look like you have completed Part 73.
#
# You are missing the file x-1545_abc.ogg.mp3.  It does not look like you have completed Part 77.
#
# You are missing the file x-1666_abc.ogg.mp3.  It does not look like you have completed Part 81.
#
# You are missing the file x-1814_abc.ogg.mp3.  It does not look like you have completed Part 85.
#
# You are missing the file x-1901_abc.ogg.mp3.  It does not look like you have completed Part 89.
# Your assignment zip file has been created!
# Now submit the file:
# /Users/aa/Developer/courses/CreativeApps-DL/CADL/session-5/music-rnn/Atul_Acharya-CADL-Project.zip
# to Kadenze for grading!

# %% [markdown]
# # Future Work
#
# Several enhancements can be performed for future work. Some of these are:
#  - Read music directly from music scores (using music21)
#  - Train for atleast 100,000 iterations for a larger LSTM network, beyond 3-layers
#  - Provide a 'priming' for text input
#  - Obtain larger datasets, both for Musical score and Dylan's writings
#  - Explore [Music Information Retrieval](http://musicinformationretrieval.com/) project for audio processing
#  - Generate polyphonic music rather than just mono-phonic
#  - Explore [Google's Magenta Project](https://magenta.tensorflow.org/welcome-to-magenta)

# %% [markdown]
# # References
#
# A few of the references that helped me. More useful for future work.
# - Andrej Karpathy - Unreasonable Effectiveness of RNN https://karpathy.github.io/2015/05/21/rnn-effectiveness/
# - Music Generation using RNN — with char-rnn https://maraoz.com/2016/02/02/abc-rnn/
# - Analyzing Deep Learning Tools for Music Generation — Asimov Institute http://www.asimovinstitute.org/analyzing-deep-learning-tools-music/
# - Hexahedria - Daniel Johnson — Composing Music with RNN
# http://www.hexahedria.com/2015/08/03/composing-music-with-recurrent-neural-networks/
# - Kyle McDonald — Creative AI - Return to ML -
# https://medium.com/@kcimc/a-return-to-machine-learning-2de3728558eb#.66hboziec
# - Folk Music Generation — Bob Sturm
# https://highnoongmt.wordpress.com/2015/05/22/lisls-stis-recurrent-neural-networks-for-folk-music-generation/
# - WaveNet — DeepMind — Keras Implementation - https://github.com/basveeling/wavenet/
